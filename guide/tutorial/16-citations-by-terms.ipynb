# %% [markdown]
# # Citations by terms

# %%
import pandas as pd
from techminer import RecordsDataFrame

rdf = RecordsDataFrame(
    pd.read_json(
        'step-07.json', 
        orient='records', 
        lines=True))

# %%
rdf.citations_by_terms('keywords (cleaned)', sep=';', top_n=20)
# Out:
#             keywords (cleaned)  Cited by
# 0                  forecasting     613.0
# 1                deep learning     541.0
# 2    recurrent neural networks     459.0
# 3   artificial neural networks     425.0
# 4                     commerce     414.0
# 5                      finance     344.0
# 6             machine learning     316.0
# 7                  Classifiers     280.0
# 8            Financial markets     273.0
# 9                stock markets     267.0
# 10                  embeddings     267.0
# 11                 time series     244.0
# 12                 transaction     236.0
# 13           granger causality     235.0
# 14                     trading     232.0
# 15                  Prediction     230.0
# 16                      Market     230.0
# 17                       Water     230.0
# 18                 Time Series     230.0
# 19                       Human     230.0
