# %% [markdown]
# # Chord diagram

# %%
import pandas as pd
from techminer import RecordsDataFrame

rdf = RecordsDataFrame(
    pd.read_json(
        'step-07.json', 
        orient='records', 
        lines=True))

# %%
rdf.autocorr(
    column='Authors',
    sep=',',
    top_n=20).heatmap()

# %%
rdf.autocorr(
    column='Authors',
    sep=',',
    top_n=20).chord_diagram()
