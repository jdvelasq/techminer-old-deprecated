# %% [markdown]
# # Terms by terms

# %%
import pandas as pd
from techminer import RecordsDataFrame

rdf = RecordsDataFrame(
    pd.read_json(
        'step-07.json', 
        orient='records', 
        lines=True))

# %%
rdf.terms_by_terms(
    column_r='Source title', 
    column_c='keywords (cleaned)', 
    sep_r=None, 
    sep_c=';',
    top_n=20).head()
# Out:
#                               Source title  \
# 0  ACM International Conference Pr... [11]
# 1  ACM International Conference Pr... [11]
# 2  ACM International Conference Pr... [11]
# 3  ACM International Conference Pr... [11]
# 4  ACM International Conference Pr... [11]
#
#                         keywords (cleaned)  Num Documents        ID
# 0                   Financial markets [27]              1  [[*75*]]
# 1          artificial neural networks [30]              1  [[*75*]]
# 2                               costs [11]              1  [[*75*]]
# 3                         forecasting [41]              1  [[*75*]]
# 4  long short-term memory neural n... [24]              1  [[*75*]]

# %%
rdf.terms_by_terms(
    column_r='Source title', 
    column_c='keywords (cleaned)', 
    sep_r=None, 
    sep_c=';',
    top_n=10).tomatrix()
# Out:
#                                          Financial markets [22]  \
# Advances in Intelligent Systems... [12]                       1
# Applied Soft Computing Journal ... [14]                       1
# Communications in Computer and ... [14]                       2
# Expert Systems with Application... [20]                       1
# IEEE Access [25]                                              2
# Lecture Notes in Computer Scien... [81]                      11
# Neural Computing and Applicatio... [7]                        0
# Neurocomputing [7]                                            1
# Procedia Computer Science [24]                                3
# Proceedings - 17th IEEE Interna... [5]                        0
#
#                                          commerce [17]  deep learning [26]  \
# Advances in Intelligent Systems... [12]              1                   1
# Applied Soft Computing Journal ... [14]              2                   2
# Communications in Computer and ... [14]              1                   2
# Expert Systems with Application... [20]              2                   2
# IEEE Access [25]                                     2                   2
# Lecture Notes in Computer Scien... [81]              6                  10
# Neural Computing and Applicatio... [7]               0                   2
# Neurocomputing [7]                                   0                   1
# Procedia Computer Science [24]                       2                   3
# Proceedings - 17th IEEE Interna... [5]               1                   1
#
#                                          forecasting [31]  \
# Advances in Intelligent Systems... [12]                 2
# Applied Soft Computing Journal ... [14]                 2
# Communications in Computer and ... [14]                 2
# Expert Systems with Application... [20]                 2
# IEEE Access [25]                                        4
# Lecture Notes in Computer Scien... [81]                14
# Neural Computing and Applicatio... [7]                  1
# Neurocomputing [7]                                      1
# Procedia Computer Science [24]                          2
# Proceedings - 17th IEEE Interna... [5]                  1
#
#                                          long short-term memory neural n... [18]  \
# Advances in Intelligent Systems... [12]                                        1
# Applied Soft Computing Journal ... [14]                                        0
# Communications in Computer and ... [14]                                        1
# Expert Systems with Application... [20]                                        2
# IEEE Access [25]                                                               1
# Lecture Notes in Computer Scien... [81]                                       10
# Neural Computing and Applicatio... [7]                                         0
# Neurocomputing [7]                                                             1
# Procedia Computer Science [24]                                                 1
# Proceedings - 17th IEEE Interna... [5]                                         1
#
#                                          recurrent neural networks [14]  \
# Advances in Intelligent Systems... [12]                               2
# Applied Soft Computing Journal ... [14]                               2
# Communications in Computer and ... [14]                               1
# Expert Systems with Application... [20]                               2
# IEEE Access [25]                                                      3
# Lecture Notes in Computer Scien... [81]                               3
# Neural Computing and Applicatio... [7]                                1
# Neurocomputing [7]                                                    0
# Procedia Computer Science [24]                                        0
# Proceedings - 17th IEEE Interna... [5]                                0
#
#                                          time series [26]  trading [22]  \
# Advances in Intelligent Systems... [12]                 2             2
# Applied Soft Computing Journal ... [14]                 1             1
# Communications in Computer and ... [14]                 2             2
# Expert Systems with Application... [20]                 2             2
# IEEE Access [25]                                        4             2
# Lecture Notes in Computer Scien... [81]                 8             9
# Neural Computing and Applicatio... [7]                  2             0
# Neurocomputing [7]                                      0             1
# Procedia Computer Science [24]                          4             3
# Proceedings - 17th IEEE Interna... [5]                  1             0
#
#                                          artificial neural networks [20]  \
# Advances in Intelligent Systems... [12]                                0
# Applied Soft Computing Journal ... [14]                                2
# Communications in Computer and ... [14]                                1
# Expert Systems with Application... [20]                                2
# IEEE Access [25]                                                       4
# Lecture Notes in Computer Scien... [81]                                6
# Neural Computing and Applicatio... [7]                                 0
# Neurocomputing [7]                                                     2
# Procedia Computer Science [24]                                         3
# Proceedings - 17th IEEE Interna... [5]                                 0
#
#                                          time series forecasting [13]
# Advances in Intelligent Systems... [12]                             0
# Applied Soft Computing Journal ... [14]                             1
# Communications in Computer and ... [14]                             0
# Expert Systems with Application... [20]                             3
# IEEE Access [25]                                                    1
# Lecture Notes in Computer Scien... [81]                             4
# Neural Computing and Applicatio... [7]                              1
# Neurocomputing [7]                                                  0
# Procedia Computer Science [24]                                      3
# Proceedings - 17th IEEE Interna... [5]                              0
