# %% [markdown]
# # Terms by terms by year

# %%
import pandas as pd
from techminer import RecordsDataFrame

rdf = RecordsDataFrame(
    pd.read_json(
        'step-07.json', 
        orient='records', 
        lines=True))

# %%
rdf.terms_by_terms_by_year(
    column_r='Authors', 
    column_c='keywords (cleaned)', 
    sep_r=',', 
    sep_c=';',
    top_n=5)
# Out:
#            Authors keywords (cleaned)  Year  Num Documents                  ID
# 2033  Hernandez G.  Financial markets  2018              2   [[*94*], [*100*]]
# 2045  Hernandez G.      deep learning  2018              2   [[*94*], [*100*]]
# 2048  Hernandez G.        forecasting  2018              2   [[*94*], [*100*]]
# 2059  Hernandez G.        time series  2018              2   [[*94*], [*100*]]
# 2061  Hernandez G.            trading  2018              1            [[*94*]]
# 2062  Hernandez G.            trading  2019              1            [[*52*]]
# 5700      Tefas A.  Financial markets  2017              2  [[*110*], [*114*]]
# 5720      Tefas A.      deep learning  2017              1           [[*114*]]
# 5727      Tefas A.        forecasting  2017              2  [[*110*], [*114*]]
# 5728      Tefas A.        forecasting  2019              1             [[*8*]]
# 5748      Tefas A.        time series  2017              2  [[*110*], [*114*]]
# ...

# %%
rdf.terms_by_terms_by_year(
    column_r='Authors', 
    column_c='keywords (cleaned)', 
    sep_r=',', 
    sep_c=';',
    top_n=5).print_IDs()
# Out:
# Hernandez G., Financial markets, 2018 (2) : [*94*][*100*]
# Hernandez G., deep learning, 2018 (2) : [*94*][*100*]
# Hernandez G., forecasting, 2018 (2) : [*94*][*100*]
# Hernandez G., time series, 2018 (2) : [*94*][*100*]
# Hernandez G., trading, 2018 (1) : [*94*]
# Hernandez G., trading, 2019 (1) : [*52*]
# Tefas A., Financial markets, 2017 (2) : [*110*][*114*]
# Tefas A., deep learning, 2017 (1) : [*114*]
# Tefas A., forecasting, 2017 (2) : [*110*][*114*]
# Tefas A., forecasting, 2019 (1) : [*8*]
# Tefas A., time series, 2017 (2) : [*110*][*114*]
# Tefas A., time series, 2019 (1) : [*8*]
# Tefas A., trading, 2017 (2) : [*110*][*114*]
# Wang J., Financial markets, 2016 (2) : [*128*][*128*]
# Wang J., Financial markets, 2019 (1) : [*3*]
# Wang J., deep learning, 2016 (2) : [*128*][*128*]
# Wang J., deep learning, 2018 (1) : [*87*]
# Wang J., deep learning, 2019 (2) : [*3*][*15*]
# Wang J., forecasting, 2016 (2) : [*128*][*128*]
# Wang J., forecasting, 2018 (1) : [*87*]
# ...
