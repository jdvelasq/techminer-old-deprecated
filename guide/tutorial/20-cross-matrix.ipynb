# %% [markdown]
# # Crosscorrelation matrix

# %%
import pandas as pd
from techminer import RecordsDataFrame

rdf = RecordsDataFrame(
    pd.read_json(
        'step-07.json', 
        orient='records', 
        lines=True))

# %%
rdf.crosscorr(
    column_r='keywords (cleaned)',
    sep_r=';',
    column_c='Authors',
    sep_c=',',
    top_n=20
).head(30)
# Out:
#                             keywords (cleaned)            Authors  \
# 0                                   costs [21]         Zhu Y. [3]
# 1                   financial time series [38]       Zhang G. [4]
# 2   long short-term memory neural network [54]          Wu J. [3]
# 3                   financial time series [38]        Chen Y. [2]
# 4                                 trading [65]         Zhu Y. [3]
# 5            convolutional neural network [29]         Zhu Y. [3]
# 6                       Financial markets [68]         Zhu Y. [3]
# 7                           deep learning [76]         Yan X. [3]
# 8                       stock forecasting [34]         Zhu Y. [3]
# 9                        machine learning [35]          Wu J. [3]
# 10  long short-term memory neural network [54]          Bu H. [2]
# 11                  financial time series [38]         Zhu Y. [3]
# 12                  financial time series [38]       Zhang Y. [3]
# 13                          deep learning [76]        Wang J. [7]
# 14                            time series [91]    Passalis N. [3]
# 15                            time series [91]   Iosifidis A. [3]
# 16                            time series [91]  Kanniainen J. [3]
# 17                            time series [91]     Gabbouj M. [3]
# 18                            time series [91]       Tefas A. [3]
# 19                time series forecasting [43]       Zhang Y. [3]
# 20                                trading [65]      Liu C.-L. [2]
# 21                                trading [65]        Leon D. [2]
# 22                          deep learning [76]       Zhang G. [4]
# 23                       machine learning [35]       Zhang G. [4]
# 24                           forecasting [108]     Gabbouj M. [3]
# 25                           forecasting [108]         Zhu Y. [3]
# 26                           forecasting [108]  Kanniainen J. [3]
# 27                           forecasting [108]    Passalis N. [3]
# 28                           forecasting [108]   Iosifidis A. [3]
# 29                           forecasting [108]       Tefas A. [3]
#
#     Crosscorrelation                                ID
# 0           0.251976                  [[*88*], [*89*]]
# 1           0.243332        [[*78*], [*117*], [*119*]]
# 2           0.235702         [[*34*], [*66*], [*115*]]
# 3           0.229416                  [[*46*], [*66*]]
# 4           0.214834          [[*78*], [*88*], [*89*]]
# 5           0.214423                  [[*78*], [*89*]]
# 6           0.210042          [[*78*], [*88*], [*89*]]
# 7           0.198680          [[*13*], [*44*], [*85*]]
# 8           0.198030                  [[*78*], [*89*]]
# 9           0.195180                  [[*34*], [*66*]]
# 10          0.192450                 [[*66*], [*115*]]
# 11          0.187317                  [[*78*], [*88*]]
# 12          0.187317                  [[*6*], [*109*]]
# 13          0.187317  [[*3*], [*15*], [*87*], [*128*]]
# 14          0.181568         [[*8*], [*110*], [*114*]]
# 15          0.181568         [[*8*], [*110*], [*114*]]
# 16          0.181568         [[*8*], [*110*], [*114*]]
# 17          0.181568         [[*8*], [*110*], [*114*]]
# 18          0.181568         [[*8*], [*110*], [*114*]]
# 19          0.176090                    [[*4*], [*6*]]
# 20          0.175412                  [[*19*], [*42*]]
# 21          0.175412                  [[*52*], [*94*]]
# 22          0.172062         [[*27*], [*78*], [*117*]]
# 23          0.169031                 [[*27*], [*117*]]
# 24          0.166667         [[*8*], [*110*], [*114*]]
# 25          0.166667          [[*78*], [*88*], [*89*]]
# 26          0.166667         [[*8*], [*110*], [*114*]]
# 27          0.166667         [[*8*], [*110*], [*114*]]
# 28          0.166667         [[*8*], [*110*], [*114*]]
# 29          0.166667         [[*8*], [*110*], [*114*]]

# %%
rdf.crosscorr(
    column_r='keywords (cleaned)',
    sep_r=';',
    column_c='Authors',
    sep_c=',',
    top_n=20
).print_IDs()
# Out:
# costs [21], Zhu Y. [3] (2) : [*88*][*89*]
# financial time series [38], Zhang G. [4] (3) : [*78*][*117*][*119*]
# long short-term memory neural network [54], Wu J. [3] (3) : [*34*][*66*][*115*]
# financial time series [38], Chen Y. [2] (2) : [*46*][*66*]
# trading [65], Zhu Y. [3] (3) : [*78*][*88*][*89*]
# convolutional neural network [29], Zhu Y. [3] (2) : [*78*][*89*]
# Financial markets [68], Zhu Y. [3] (3) : [*78*][*88*][*89*]
# deep learning [76], Yan X. [3] (3) : [*13*][*44*][*85*]
# stock forecasting [34], Zhu Y. [3] (2) : [*78*][*89*]
# machine learning [35], Wu J. [3] (2) : [*34*][*66*]
# long short-term memory neural network [54], Bu H. [2] (2) : [*66*][*115*]
# financial time series [38], Zhu Y. [3] (2) : [*78*][*88*]
# financial time series [38], Zhang Y. [3] (2) : [*6*][*109*]
# deep learning [76], Wang J. [7] (4) : [*3*][*15*][*87*][*128*]
# time series [91], Passalis N. [3] (3) : [*8*][*110*][*114*]
# time series [91], Iosifidis A. [3] (3) : [*8*][*110*][*114*]
# time series [91], Kanniainen J. [3] (3) : [*8*][*110*][*114*]
# time series [91], Gabbouj M. [3] (3) : [*8*][*110*][*114*]
# time series [91], Tefas A. [3] (3) : [*8*][*110*][*114*]
# time series forecasting [43], Zhang Y. [3] (2) : [*4*][*6*]
# trading [65], Liu C.-L. [2] (2) : [*19*][*42*]
# trading [65], Leon D. [2] (2) : [*52*][*94*]
# deep learning [76], Zhang G. [4] (3) : [*27*][*78*][*117*]
# machine learning [35], Zhang G. [4] (2) : [*27*][*117*]
# forecasting [108], Gabbouj M. [3] (3) : [*8*][*110*][*114*]
# forecasting [108], Zhu Y. [3] (3) : [*78*][*88*][*89*]
# forecasting [108], Kanniainen J. [3] (3) : [*8*][*110*][*114*]
# forecasting [108], Passalis N. [3] (3) : [*8*][*110*][*114*]
# forecasting [108], Iosifidis A. [3] (3) : [*8*][*110*][*114*]
# forecasting [108], Tefas A. [3] (3) : [*8*][*110*][*114*]
# deep learning [76], Liu C.-L. [2] (2) : [*19*][*42*]
# deep learning [76], Li Y. [2] (2) : [*40*][*97*]
# recurrent neural networks [52], Zhu Y. [3] (2) : [*88*][*89*]
# time series [91], Zhang G. [4] (3) : [*78*][*117*][*119*]
# long short-term memory neural network [54], Zhang Y. [3] (2) : [*4*][*6*]
# long short-term memory neural network [54], Zhu Y. [3] (2) : [*88*][*89*]
# forecasting [108], Wang J. [7] (4) : [*3*][*15*][*87*][*128*]
# convolution [21], Bu H. [2] (1) : [*66*]
# costs [21], Leon D. [2] (1) : [*94*]
# convolution [21], Liu C.-L. [2] (1) : [*19*]
# convolution [21], Oosterlee C.W. [2] (1) : [*18*]
# convolution [21], Chen Y. [2] (1) : [*66*]
# time series [91], Li Y. [2] (2) : [*40*][*97*]
# commerce [61], Tefas A. [3] (2) : [*110*][*114*]
# commerce [61], Iosifidis A. [3] (2) : [*110*][*114*]
# commerce [61], Zhang Y. [3] (2) : [*4*][*6*]
# commerce [61], Wu J. [3] (2) : [*34*][*66*]
# commerce [61], Passalis N. [3] (2) : [*110*][*114*]
# commerce [61], Kanniainen J. [3] (2) : [*110*][*114*]
# commerce [61], Zhu Y. [3] (2) : [*78*][*89*]
# commerce [61], Gabbouj M. [3] (2) : [*110*][*114*]
# artificial neural networks [62], Gabbouj M. [3] (2) : [*110*][*114*]
# artificial neural networks [62], Zhu Y. [3] (2) : [*78*][*89*]
# artificial neural networks [62], Passalis N. [3] (2) : [*110*][*114*]
# artificial neural networks [62], Zhang Y. [3] (2) : [*4*][*6*]
# artificial neural networks [62], Iosifidis A. [3] (2) : [*110*][*114*]
# artificial neural networks [62], Tefas A. [3] (2) : [*110*][*114*]
# artificial neural networks [62], Kanniainen J. [3] (2) : [*110*][*114*]
# feedforward neural networks [24], Bu H. [2] (1) : [*115*]
# feedforward neural networks [24], Chen Y. [2] (1) : [*46*]
# forecasting [108], Zhang G. [4] (3) : [*78*][*117*][*119*]
# trading [65], Tefas A. [3] (2) : [*110*][*114*]
# trading [65], Passalis N. [3] (2) : [*110*][*114*]
# trading [65], Sandoval J. [3] (2) : [*52*][*94*]
# trading [65], Iosifidis A. [3] (2) : [*110*][*114*]
# trading [65], Zhang Y. [3] (2) : [*4*][*6*]
# trading [65], Arévalo A. [3] (2) : [*52*][*94*]
# trading [65], Wu J. [3] (2) : [*34*][*66*]
# trading [65], Hernandez G. [3] (2) : [*52*][*94*]
# trading [65], Kanniainen J. [3] (2) : [*110*][*114*]
# trading [65], Gabbouj M. [3] (2) : [*110*][*114*]
# Financial markets [68], Wu J. [3] (2) : [*34*][*66*]
# stock forecasting [34], Wang J. [7] (2) : [*3*][*128*]
# Financial markets [68], Kanniainen J. [3] (2) : [*110*][*114*]
# Financial markets [68], Arévalo A. [3] (2) : [*94*][*100*]
# Financial markets [68], Gabbouj M. [3] (2) : [*110*][*114*]
# Financial markets [68], Zhang Y. [3] (2) : [*4*][*6*]
# Financial markets [68], Iosifidis A. [3] (2) : [*110*][*114*]
# Financial markets [68], Sandoval J. [3] (2) : [*94*][*100*]
# Financial markets [68], Tefas A. [3] (2) : [*110*][*114*]
# Financial markets [68], Hernandez G. [3] (2) : [*94*][*100*]
# Financial markets [68], Passalis N. [3] (2) : [*110*][*114*]
# machine learning [35], Wang J. [7] (2) : [*10*][*15*]
# forecasting [108], Li Y. [2] (2) : [*40*][*97*]
# forecasting [108], Oosterlee C.W. [2] (2) : [*18*][*120*]
# long short-term memory neural network [54], Zhang G. [4] (2) : [*117*][*119*]
# deep learning [76], Hernandez G. [3] (2) : [*94*][*100*]
# deep learning [76], Wu J. [3] (2) : [*34*][*66*]
# deep learning [76], Arévalo A. [3] (2) : [*94*][*100*]
# deep learning [76], Zhang Y. [3] (2) : [*4*][*109*]
# deep learning [76], Sandoval J. [3] (2) : [*94*][*100*]
# deep learning [76], Zhu Y. [3] (2) : [*78*][*89*]
# convolutional neural network [29], Liu C.-L. [2] (1) : [*19*]
# convolutional neural network [29], Oosterlee C.W. [2] (1) : [*18*]
# time series [91], Wang J. [7] (3) : [*3*][*15*][*87*]
# financial data [31], Liu C.-L. [2] (1) : [*19*]
# financial data [31], Chen Y. [2] (1) : [*46*]
# costs [21], Kanniainen J. [3] (1) : [*110*]
# costs [21], Wu J. [3] (1) : [*34*]
# costs [21], Passalis N. [3] (1) : [*110*]
# costs [21], Tefas A. [3] (1) : [*110*]
# costs [21], Arévalo A. [3] (1) : [*94*]
# costs [21], Iosifidis A. [3] (1) : [*110*]
# convolution [21], Kanniainen J. [3] (1) : [*114*]
# costs [21], Sandoval J. [3] (1) : [*94*]
# convolution [21], Passalis N. [3] (1) : [*114*]
# convolution [21], Wu J. [3] (1) : [*66*]
# convolution [21], Iosifidis A. [3] (1) : [*114*]
# convolution [21], Tefas A. [3] (1) : [*114*]
# costs [21], Hernandez G. [3] (1) : [*94*]
# costs [21], Gabbouj M. [3] (1) : [*110*]
# convolution [21], Zhu Y. [3] (1) : [*78*]
# convolution [21], Gabbouj M. [3] (1) : [*114*]
# time series forecasting [43], Wang J. [7] (2) : [*80*][*87*]
# trading [65], Zhang G. [4] (2) : [*78*][*119*]
# forecasting accuracy [22], Kanniainen J. [3] (1) : [*110*]
# forecasting accuracy [22], Iosifidis A. [3] (1) : [*110*]
# forecasting accuracy [22], Zhang Y. [3] (1) : [*4*]
# forecasting accuracy [22], Tefas A. [3] (1) : [*110*]
# forecasting accuracy [22], Gabbouj M. [3] (1) : [*110*]
# forecasting accuracy [22], Passalis N. [3] (1) : [*110*]
# Financial markets [68], Zhang G. [4] (2) : [*78*][*119*]
# stock forecasting [34], Chen Y. [2] (1) : [*66*]
# stock forecasting [34], Oosterlee C.W. [2] (1) : [*18*]
# stock forecasting [34], Bu H. [2] (1) : [*66*]
# stock forecasting [34], Liu C.-L. [2] (1) : [*42*]
# stock forecasting [34], Leon D. [2] (1) : [*94*]
# time series [91], Zhu Y. [3] (2) : [*78*][*89*]
# time series [91], Yan X. [3] (2) : [*44*][*85*]
# time series [91], Hernandez G. [3] (2) : [*94*][*100*]
# time series [91], Sandoval J. [3] (2) : [*94*][*100*]
# time series [91], Zhang Y. [3] (2) : [*6*][*109*]
# time series [91], Arévalo A. [3] (2) : [*94*][*100*]
# machine learning [35], Liu C.-L. [2] (1) : [*19*]
# machine learning [35], Chen Y. [2] (1) : [*66*]
# machine learning [35], Bu H. [2] (1) : [*66*]
# finance [35], Li Y. [2] (1) : [*97*]
# finance [35], Liu C.-L. [2] (1) : [*19*]
# finance [35], Chen Y. [2] (1) : [*46*]
# feedforward neural networks [24], Wu J. [3] (1) : [*115*]
# feedforward neural networks [24], Iosifidis A. [3] (1) : [*110*]
# feedforward neural networks [24], Gabbouj M. [3] (1) : [*110*]
# feedforward neural networks [24], Passalis N. [3] (1) : [*110*]
# feedforward neural networks [24], Zhu Y. [3] (1) : [*88*]
# feedforward neural networks [24], Kanniainen J. [3] (1) : [*110*]
# feedforward neural networks [24], Tefas A. [3] (1) : [*110*]
# financial time series [38], Bu H. [2] (1) : [*66*]
# financial time series [38], Oosterlee C.W. [2] (1) : [*18*]
# financial time series [38], Liu C.-L. [2] (1) : [*19*]
# forecasting [108], Hernandez G. [3] (2) : [*94*][*100*]
# forecasting [108], Zhang Y. [3] (2) : [*4*][*6*]
# forecasting [108], Arévalo A. [3] (2) : [*94*][*100*]
# forecasting [108], Wu J. [3] (2) : [*34*][*66*]
# forecasting [108], Sandoval J. [3] (2) : [*94*][*100*]
# convolution [21], Zhang G. [4] (1) : [*78*]
# time series forecasting [43], Li Y. [2] (1) : [*40*]
# convolutional neural network [29], Iosifidis A. [3] (1) : [*114*]
# convolutional neural network [29], Tefas A. [3] (1) : [*114*]
# convolutional neural network [29], Yan X. [3] (1) : [*13*]
# convolutional neural network [29], Gabbouj M. [3] (1) : [*114*]
# convolutional neural network [29], Passalis N. [3] (1) : [*114*]
# convolutional neural network [29], Kanniainen J. [3] (1) : [*114*]
# financial data [31], Arévalo A. [3] (1) : [*100*]
# financial data [31], Sandoval J. [3] (1) : [*100*]
# financial data [31], Hernandez G. [3] (1) : [*100*]
# financial data [31], Zhang Y. [3] (1) : [*109*]
# feedforward neural networks [24], Zhang G. [4] (1) : [*117*]
# stock forecasting [34], Arévalo A. [3] (1) : [*94*]
# stock forecasting [34], Zhang Y. [3] (1) : [*4*]
# Financial markets [68], Wang J. [7] (2) : [*3*][*128*]
# stock forecasting [34], Wu J. [3] (1) : [*66*]
# stock forecasting [34], Hernandez G. [3] (1) : [*94*]
# stock forecasting [34], Sandoval J. [3] (1) : [*94*]
# recurrent neural networks [52], Li Y. [2] (1) : [*97*]
# recurrent neural networks [52], Chen Y. [2] (1) : [*46*]
# machine learning [35], Passalis N. [3] (1) : [*114*]
# finance [35], Yan X. [3] (1) : [*85*]
# machine learning [35], Tefas A. [3] (1) : [*114*]
# machine learning [35], Iosifidis A. [3] (1) : [*114*]
# finance [35], Zhang Y. [3] (1) : [*109*]
# machine learning [35], Zhang Y. [3] (1) : [*6*]
# machine learning [35], Gabbouj M. [3] (1) : [*114*]
# machine learning [35], Kanniainen J. [3] (1) : [*114*]
# finance [35], Wu J. [3] (1) : [*34*]
# finance [35], Zhu Y. [3] (1) : [*89*]
# long short-term memory neural network [54], Chen Y. [2] (1) : [*66*]
# long short-term memory neural network [54], Liu C.-L. [2] (1) : [*42*]
# financial time series [38], Wu J. [3] (1) : [*66*]
# financial time series [38], Iosifidis A. [3] (1) : [*114*]
# financial time series [38], Tefas A. [3] (1) : [*114*]
# financial time series [38], Passalis N. [3] (1) : [*114*]
# financial time series [38], Yan X. [3] (1) : [*13*]
# financial time series [38], Kanniainen J. [3] (1) : [*114*]
# financial time series [38], Gabbouj M. [3] (1) : [*114*]
# convolutional neural network [29], Zhang G. [4] (1) : [*78*]
# commerce [61], Chen Y. [2] (1) : [*66*]
# commerce [61], Liu C.-L. [2] (1) : [*19*]
# commerce [61], Leon D. [2] (1) : [*94*]
# commerce [61], Li Y. [2] (1) : [*97*]
# commerce [61], Bu H. [2] (1) : [*66*]
# artificial neural networks [62], Chen Y. [2] (1) : [*46*]
# artificial neural networks [62], Oosterlee C.W. [2] (1) : [*18*]
# artificial neural networks [62], Bu H. [2] (1) : [*115*]
# artificial neural networks [62], Leon D. [2] (1) : [*94*]
# artificial neural networks [62], Liu C.-L. [2] (1) : [*19*]
# artificial neural networks [62], Li Y. [2] (1) : [*97*]
# financial data [31], Zhang G. [4] (1) : [*117*]
# costs [21], Wang J. [7] (1) : [*128*]
# convolution [21], Wang J. [7] (1) : [*128*]
# time series forecasting [43], Arévalo A. [3] (1) : [*100*]
# time series forecasting [43], Sandoval J. [3] (1) : [*100*]
# time series forecasting [43], Passalis N. [3] (1) : [*8*]
# time series forecasting [43], Kanniainen J. [3] (1) : [*8*]
# time series forecasting [43], Gabbouj M. [3] (1) : [*8*]
# time series forecasting [43], Hernandez G. [3] (1) : [*100*]
# time series forecasting [43], Tefas A. [3] (1) : [*8*]
# time series forecasting [43], Iosifidis A. [3] (1) : [*8*]
# trading [65], Chen Y. [2] (1) : [*66*]
# trading [65], Oosterlee C.W. [2] (1) : [*18*]
# trading [65], Bu H. [2] (1) : [*66*]
# trading [65], Li Y. [2] (1) : [*97*]
# Financial markets [68], Leon D. [2] (1) : [*94*]
# stock forecasting [34], Zhang G. [4] (1) : [*78*]
# Financial markets [68], Chen Y. [2] (1) : [*66*]
# Financial markets [68], Oosterlee C.W. [2] (1) : [*18*]
# Financial markets [68], Bu H. [2] (1) : [*66*]
# Financial markets [68], Liu C.-L. [2] (1) : [*42*]
# Financial markets [68], Li Y. [2] (1) : [*97*]
# finance [35], Zhang G. [4] (1) : [*117*]
# deep learning [76], Chen Y. [2] (1) : [*66*]
# deep learning [76], Oosterlee C.W. [2] (1) : [*120*]
# deep learning [76], Bu H. [2] (1) : [*66*]
# deep learning [76], Leon D. [2] (1) : [*94*]
# recurrent neural networks [52], Zhang Y. [3] (1) : [*6*]
# recurrent neural networks [52], Passalis N. [3] (1) : [*8*]
# recurrent neural networks [52], Kanniainen J. [3] (1) : [*8*]
# recurrent neural networks [52], Iosifidis A. [3] (1) : [*8*]
# recurrent neural networks [52], Gabbouj M. [3] (1) : [*8*]
# recurrent neural networks [52], Tefas A. [3] (1) : [*8*]
# long short-term memory neural network [54], Gabbouj M. [3] (1) : [*110*]
# long short-term memory neural network [54], Kanniainen J. [3] (1) : [*110*]
# long short-term memory neural network [54], Passalis N. [3] (1) : [*110*]
# long short-term memory neural network [54], Iosifidis A. [3] (1) : [*110*]
# long short-term memory neural network [54], Tefas A. [3] (1) : [*110*]
# time series forecasting [43], Zhang G. [4] (1) : [*117*]
# convolutional neural network [29], Wang J. [7] (1) : [*128*]
# time series [91], Chen Y. [2] (1) : [*46*]
# time series [91], Leon D. [2] (1) : [*94*]
# time series [91], Liu C.-L. [2] (1) : [*19*]
# time series [91], Oosterlee C.W. [2] (1) : [*18*]
# commerce [61], Sandoval J. [3] (1) : [*94*]
# commerce [61], Arévalo A. [3] (1) : [*94*]
# commerce [61], Hernandez G. [3] (1) : [*94*]
# artificial neural networks [62], Wu J. [3] (1) : [*115*]
# artificial neural networks [62], Hernandez G. [3] (1) : [*94*]
# artificial neural networks [62], Sandoval J. [3] (1) : [*94*]
# artificial neural networks [62], Arévalo A. [3] (1) : [*94*]
# forecasting [108], Liu C.-L. [2] (1) : [*42*]
# forecasting [108], Bu H. [2] (1) : [*66*]
# forecasting [108], Chen Y. [2] (1) : [*66*]
# forecasting [108], Leon D. [2] (1) : [*94*]
# deep learning [76], Tefas A. [3] (1) : [*114*]
# deep learning [76], Iosifidis A. [3] (1) : [*114*]
# deep learning [76], Passalis N. [3] (1) : [*114*]
# deep learning [76], Kanniainen J. [3] (1) : [*114*]
# deep learning [76], Gabbouj M. [3] (1) : [*114*]
# commerce [61], Zhang G. [4] (1) : [*78*]
# artificial neural networks [62], Zhang G. [4] (1) : [*78*]
# recurrent neural networks [52], Wang J. [7] (1) : [*80*]
# forecasting [108], Yan X. [3] (1) : [*13*]
# long short-term memory neural network [54], Wang J. [7] (1) : [*128*]
# commerce [61], Wang J. [7] (1) : [*3*]
# artificial neural networks [62], Wang J. [7] (1) : [*10*]
# trading [65], Wang J. [7] (1) : [*3*]
