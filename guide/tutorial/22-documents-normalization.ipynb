# %% [markdown]
# # Document normalization

# %%
import sys
import os

sys.path.append(os.path.abspath('..//../techminer/'))
from docs_normalizer import DocNormalizer
import pandas as pd
from techminer import RecordsDataFrame

# %%
rdf = RecordsDataFrame(
    pd.read_json(
        '..\\..\\data\\cleaned.json', 
        orient='records', 
        lines=True))

# %%
rdf
# Out:
#                                               Abstract  Access Type  \
# 0    The importance of an interference-less machine...         None
# 1    This paper proposes a novel application of dee...         None
# 2    A novel type of recurrent neural network, the ...         None
# 3    Computational technologies have offered faster...         None
# 4    Deep learning has recently received growing in...         None
# 5    This paper presents improvements in financial ...         None
# 6    In this paper, we develop a new Hybrid method ...         None
# 7    Forecasting a financial asset's price is impor...         None
# 8    Most approaches to forecasting time series dat...         None
# 9    A low complexity Polynomial Functional link Ar...         None
# 10   Opponents of the efficient markets hypothesis ...         None
# 11   Time series analysis is an important field tha...         None
# 12   In recent years the advancement in neural netw...         None
# 13   We present a method for conditional time serie...         None
# 14   Forecasting financial time series using past o...         None
# 15   Deep Learning is a consolidated, state-of-the-...         None
# 16   Predicting the future value of the stock is ve...         None
# 17   Forecasting volatility is an important issue i...         None
# 18   To forecast the future trend of financial acti...         None
# 19   A novel financial time-series analysis method ...         None
# 20   Stock market prediction has attracted a lot of...         None
# 21   It has always been a challenging issue for peo...         None
# 22   Stock market prediction plays an important rol...         None
# 23   With the advent of the artificial intelligence...         None
# 24   Multivariate time series forecasting involves ...         None
# 25   In this paper we propose a new neural networks...         None
# 26   We present an Artificial Neural Network (ANN) ...         None
# 27   This paper is intended as a follow up to a pre...         None
# 28   Recurrent neural networks (RNNs) are types of ...  Open Access
# 29   Time series forecasting is one of the most eff...         None
# ..                                                 ...          ...
# 114  Given a financial time series such as S&P 500,...         None
# 115  Cash flow prediction is important. It can help...         None
# 116  Long short-term memory (LSTM) networks are a s...         None
# 117  By combining wavelet analysis with Long Short-...         None
# 118  The world economy is in a stage of rapid devel...         None
# 119  The prediction of price trend in stock market ...         None
# 120  Financial time series analysis is an important...         None
# 121  Stock market is one of the most important comp...         None
# 122  Most of the existing literature on stock price...         None
# 123  The Artificial Neural Network is widely applie...         None
# 124  This paper presents a novel deep learning appr...         None
# 125  Understanding the pattern of financial activit...         None
# 126  Forecasting the foreign exchange rate is an up...         None
# 127  Neural networks have been popular in time seri...         None
# 128  The time series of stock prices are non-statio...  Open Access
# 129  Noisy and nonstationary real-world time series...         None
# 130  Social network media analytics is showing prom...  Open Access
# 131  To predicate the future with high accuracy is ...         None
# 132  The combination of Convolutional Neural Networ...         None
# 133  Various techniques have been applied to predic...         None
# 134  Exchange rate forecasting has always been a re...         None
# 135  The Long Short-Term Memory (LSTM) model has be...         None
# 136  In this chapter we investigate a typical situa...         None
# 137  The proceedings contain 33 papers. The special...         None
# 138  The proceedings contain 26 papers. The topics ...         None
# 139  The proceedings contain 148 papers. The specia...         None
# 140  The proceedings contain 148 papers. The specia...         None
# 141  The proceedings contain 148 papers. The specia...         None
# 142  The proceedings contain 58 papers. The topics ...         None
# 143  The proceedings contain 87 papers. The special...         None
#
#                                           Affiliations  Art. No.  \
# 0    Department of Mathematics, Faculty of Science,...    112842
# 1    Faculty of Mathematics and Computer Science, W...      None
# 2    Technical University of Denmark (DTU), Bygning...      None
# 3    University of Science and Technology of China,...     e3987
# 4    School of Computer Science & Engineering, Nany...      None
# 5    Oxford-Man Institute of Quantitative Finance, ...   8673598
# 6    SKLCS, Institute of Software, Chinese Academy ...   8408524
# 7    School of Computer and Information Technology,...   8714662
# 8    School of Informatics, Aristotle University of...   8682297
# 9    Sardar Patel Institute of Technology, Mumbai, ...   8701258
# 10   School of Science, Beijing Jiaotong University...      None
# 11   School of Physics & Astronomy, University of E...      None
# 12   Computer Engineering Department, Istanbul Kult...   8741818
# 13   Foreign Trade College, Chongqing Normal Univer...   8725661
# 14   Departement of Computer Sicence and Informatio...   8679218
# 15   College of Electrical and Control Engineering,...   8729026
# 16   Department of Control System and Instrumentati...   8645980
# 17   Department of Digital Content and Technology, ...   8637486
# 18   Dipartimento di Matematica, Università di Bolo...      None
# 19     National Chiao Tung University, Hsinchu, Taiwan   8631422
# 20   Department of Computer Science, University of ...   8628641
# 21   Bilgisayar Mühendisliǧi Bölümü, Yildiz Teknik ...   8625357
# 22   Computer Science, Tennessee Technological Univ...   8622303
# 23   Department of Applied Economics, Texas Tech Un...   8614252
# 24   University of Manitoba, Winnipeg, MB, Canada; ...   8614267
# 25   School of Economics & Management, University o...      None
# 26   Institute of Analytics and Data Science, Kenne...   8606647
# 27   College of Economics, Hangzhou Dianzi Universi...      None
# 28   Department of Management Sciences, COMSATS Uni...      2980
# 29   College of Computer Science and Technology, Na...      None
# ..                                                 ...       ...
# 114  Department of Informatics, Aristotle Universit...   8010701
# 115  School of Economics and Management, Beihang Un...   7996306
# 116  Institute of Information Management, National ...   7979885
# 117  Department of Computer Science, Shanghai Unive...      None
# 118  Department of Accounting and Audit, Ternopil N...      None
# 119  Department of Computer Science, Shanghai Unive...      None
# 120  Dipartimento di Matematica, Università di Bolo...      None
# 121  Universidad Distrital Francisco José de Caldas...      None
# 122  National Information Processing Institute, War...      None
# 123  Olayan School of Business, American University...      None
# 124  Graduate School of System Informatics, Kobe Un...   7550882
# 125  Faculty of Engineering and Technology Liverpoo...      None
# 126  Faculty of Automatic Control and Computers, Un...   7426093
# 127  University of Verona, Department of Computer S...      None
# 128  School of Science, Beijing Jiaotong University...   4742515
# 129  FPF Tech, Av. Danilo Areosa 1170, Distrito-Ind...      None
# 130  G.M.R. Institute of Technology, Rajam, A.P, In...      None
# 131  Centre of Intelligent Systems and Network Rese...      None
# 132  Stevens Institute of Technology, Castle Point ...      None
# 133  European University Institute, Florence, Italy...      None
# 134  National University of Singapore, Department o...      None
# 135  School of Information Science and Technology, ...      None
# 136  Siemens AG Munich, Corporate Technology, Munic...      None
# 137  Department of Information Management, Yuanpei ...      None
# 138  Stevens Institute of Technology, School of Sys...      None
# 139  Information Technology and Multimedia Faculty,...      None
# 140  Department of Industrial Engineering and Engin...      None
# 141                                               None      None
# 142  Liverpool Business School, Centre for Internat...      None
# 143  Department of Computer Science and Technology,...   5584802
#
#                                        Author Keywords  \
# 0    Component trends; Empirical mode decomposition...
# 1                                                 None
# 2    And financial time series prediction; Dynamic ...
# 3    Artificial intelligence; Deep learning; Financ...
# 4                                                 None
# 5    Computational finance; Deep Neural Networks; D...
# 6    Anomaly detection; Long short-term memory (LST...
# 7    Data augmentation; Deep learning; Long short-t...
# 8                                                 None
# 9    AMAPE; backpropagation learning algorithm; dif...
# 10   Machine learning; Neural networks; Stock predi...
# 11   Forecasting Stock Prices; Principal Component ...
# 12   ARIMA model; Gated recurrent unit; Long short ...
# 13   Convolutional neural network (CNN); Deep learn...
# 14   Convolutional neural network; Financial time s...
# 15   Aleatoric models; Deep Learning; Time-series; ...
# 16   Artificial neural networks; Recurrent neural n...
# 17   Conditional restricted Boltzmann machine; Cova...
# 18   CNN; financial prediction; neural network; sto...
# 19   convolutional neural networks; data visualizat...
# 20   Online Social Networks; Recurrent Neural Netwo...
# 21   Embedding Method; LSTM; Market Prediction; Mar...
# 22   Financial market prediction; Particle swarm op...
# 23   Artificial Intelligence (AI); Conversational C...
# 24   Dynamic factor models; Multi-step ahead foreca...
# 25   Cryptocurrency; Deep learning; Forecasting; Ma...
# 26   Artificial neural networks; Convolutional neur...
# 27   Data science; Deep learning; Fintech; Machine ...
# 28   Futures markets; Limit order book; Recurrent n...
# 29   Artificial neural networks; Convolutional neur...
# ..                                                 ...
# 114  convolutional neural network; financial time s...
# 115  Accounts receivable; ARIMA; Cash flow predicti...
# 116  Bitcoin; cryptocurrency prediction; long-short...
# 117  Deep learning; Financial time series predictio...
# 118  convolutional neural network; financial foreca...
# 119  Financial time series; Long Short-Term Memory;...
# 120  Deep learning; Event sentiment; Forecasting; F...
# 121  LSTM; Neural network; Stock prediction; Transf...
# 122  ARIMA; CART; Similar Stock; Slide Window; Stoc...
# 123    Convolutional neural network; Stock forecasting
# 124  attention mechanism; cycle embeddings; deep re...
# 125  Deep learning; Financial data prediction; Neur...
# 126                                               None
# 127  Echo State Network; Financial time series; Pri...
# 128  Long Short-Term Memory (LSTM); Stock price pre...
# 129  Deep learning (DL); Extreme learning machine (...
# 130  Emotions; Granger causality; LSTM; Network pub...
# 131  Financial prediction; Fusion method; Represent...
# 132  CNNs; Convolution layer; Correlated temporal d...
# 133            LSTM; stock; Time series; Time weighted
# 134      DBN; Deep learning; Exchange rate forecasting
# 135  Cluster; Correlation coefficient; LSTM; Time s...
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
# 141                                               None
# 142                                               None
# 143                                               None
#
#                                           Author(s) ID  \
# 0      57210187197;24070754400;6603142390;26644170500;
# 1                 55897965200;55860046500;24337898500;
# 2                  36647999000;56724096100;7201689596;
# 3                             57207830408;57207828548;
# 4                 57196019442;56140547500;56462264800;
# 5                 57208652822;14057447500;57203276441;
# 6    55520303300;57191849336;57189032831;5720289057...
# 7                             57209140407;57209134544;
# 8    56897101400;6701672908;23394868200;7005332419;...
# 9    57208722670;57208718984;57208719870;5720872154...
# 10                            57205691331;55946707000;
# 11                57204789588;16412284700;55509976400;
# 12    57209730058;57209731841;57209734258;14054797000;
# 13                            50562404800;57206579718;
# 14                            57208408426;36816648000;
# 15    15060001900;57209464952;57209470539;57209477365;
# 16                             57207926780;6506821304;
# 17     55713072400;57207760751;57207762684;7402969813;
# 18                 57193126885;55893905100;6701797256;
# 19                 57196051044;57129735000;6507335623;
# 20   57207728673;55407386600;6602683636;8347469300;...
# 21   57207696480;57190650159;8410237700;13408912900...
# 22                57195922078;57207579157;24558789000;
# 23                57201302278;57198291892;36171214700;
# 24   57198863686;57207108540;57207114198;7402612526...
# 25                36792418900;57207322594;57189992988;
# 26                            57193344346;55710281400;
# 27                44062068800;57005856100;56949237700;
# 28   35231560800;24775626200;57210197386;5719781009...
# 29                56072612200;35315440400;57104239400;
# ..                                                 ...
# 114  57195636516;56897101400;6701672908;23394868200...
# 115               57195521810;57204073569;35313047900;
# 116  57195363174;57195360094;57195361498;8882763200...
# 117                56670483600;7404745474;56278752300;
# 118                            56205106000;7401816816;
# 119                57197735758;7404745474;56670483600;
# 120                57193126885;55893905100;6701797256;
# 121               24767828800;57189442448;56583596000;
# 122                                       57194777223;
# 123                                       36608193100;
# 124    57191226854;56425644100;53863900700;7201993612;
# 125    56212648400;23090210900;56288742400;6505760939;
# 126  57189040270;23469633000;55365937600;5718903482...
# 127                           57203636440;57192153071;
# 128   56527464300;55946707000;42361194900;55286614500;
# 129                            57169827100;8358717400;
# 130                36809160400;16642346800;7102314306;
# 131   56028822400;19639163400;56278299400;56278649100;
# 132                            55797136900;6506999405;
# 133                                        8560165000;
# 134                            57199918726;7006684979;
# 135                55366093200;56256904700;8208832700;
# 136                35615968500;23024809400;8947545100;
# 137                            23062367300;7404797459;
# 138                                       55797136900;
# 139                23388956400;56212648400;8410551000;
# 140                36188164200;35292259200;7202860325;
# 141                           [No author id available]
# 142                 6602234892;7005939268;35099556100;
# 143   35747648300;24338421700;55832871000;15124457200;
#
#                                                Authors   CONF  Cited by  \
# 0    Hajiabotorabi Z., Kazemi A., Samavati F.F., Ma...  False       NaN
# 1            Ładyżyński P., Żbikowski K., Gawrysiak P.  False       NaN
# 2                Rodrigues F., Markou I., Pereira F.C.  False       3.0
# 3                                      Cao J., Wang J.  False       NaN
# 4                      Xing F.Z., Cambria E., Zhang Y.  False       3.0
# 5                      Zhang Z., Zohren S., Roberts S.  False       NaN
# 6        Shi L., Teng Z., Wang L., Zhang Y., Binder A.  False       1.0
# 7                                   Yeze Z., Yiying W.  False       NaN
# 8    Passalis N., Tefas A., Kanniainen J., Gabbouj ...  False       NaN
# 9    Karmiani D., Kazi R., Nambisan A., Shah A., Ka...  False       NaN
# 10                                    Wang B., Wang J.  False       NaN
# 11                Moews B., Herrmann J.M., Ibikunle G.  False       1.0
# 12   Sismanoglu G., Onde M.A., Kocer F., Sahingoz O.K.  False       NaN
# 13                                     Yan X., Zhao J.  False       NaN
# 14                                  Yu M.-H., Wu J.-L.  False       NaN
# 15                     Du J., Liu Q., Chen K., Wang J.  False       NaN
# 16                       Thipprachak K., Tangamchit P.  False       NaN
# 17              Wu C.-H., Lu C.-C., Ma Y.-F., Lu R.-S.  False       1.0
# 18               Borovykh A., Bohte S., Oosterlee C.W.  False       1.0
# 19                  Huang H.-S., Liu C.-L., Tseng V.S.  False       1.0
# 20   Hossain M.A., Karim R., Thulasiram R., Bruce N...  False       1.0
# 21   Uygun Y., Erboy M.O., Aktas M.S., Kalipsiz O.,...  False       NaN
# 22            Islam S.R., Khaled Ghafoor S., Eberle W.  False       NaN
# 23        Siami-Namini S., Tavakoli N., Siami Namin A.  False       1.0
# 24   Morris K.J., Egan S.D., Linsangan J.L., Leung ...  False       1.0
# 25                              Long W., Lu Z., Cui L.  False       5.0
# 26                                       Le L., Xie Y.  False       NaN
# 27                           Zheng J., Fu X., Zhang G.  False       3.0
# 28   Yasir M., Durrani M.Y., Afzal S., Maqsood M., ...  False       NaN
# 29                           Zhang C., Dai Q., Song G.  False       NaN
# ..                                                 ...    ...       ...
# 114  Tsantekidis A., Passalis N., Tefas A., Kanniai...  False      20.0
# 115                                Li J., Bu H., Wu J.  False       8.0
# 116  Chen J.-F., Chen W.-L., Huang C.-P., Huang S.-...  False      14.0
# 117                            Zhang G., Xu L., Xue Y.  False       7.0
# 118                        Galeshchuk S., Mukherjee S.  False       1.0
# 119                             Yu H., Xu L., Zhang G.  False       1.0
# 120              Borovykh A., Bohte S., Oosterlee C.W.  False       3.0
# 121  Figueroa-García J.C., LóPez-Santana E., Franco...  False       NaN
# 122                                      Buczkowski P.  False       1.0
# 123                               Karathanasopoulos A.  False       NaN
# 124    Akita R., Yoshihara A., Matsubara T., Uehara K.  False      37.0
# 125  Hussain A.J., Al-Jumeily D., Al-Askar H., Radi N.  False      10.0
# 126  Horelu A., Leordeanu C., Apostol E., Huru D., ...  False       NaN
# 127                           Di Persio L., Honchar O.  False      19.0
# 128                  Wang J., Wang J., Fang W., Niu H.  False      19.0
# 129                         Nascimento J.B., Cristo M.  False       1.0
# 130                 Bebarta D.K., Biswal B., Dash P.K.  False       5.0
# 131     Zafari F., Khan G.M., Rehman M., Ali Mahmud S.  False       3.0
# 132                            Ortega L., Khashanah K.  False      20.0
# 133                                       Bekiros S.D.  False       2.0
# 134                           Sharma V., Srinivasan D.  False      28.0
# 135                             Cai X., Lai G., Lin X.  False       5.0
# 136  Zimmermann H.G., Grothmann R., von Mettenheim ...  False       1.0
# 137                             Wei L.-Y., Cheng C.-H.  False      14.0
# 138                                        Ortega L.F.  False       2.0
# 139               Ghazali R., Hussain A.J., Liatsis P.  False      42.0
# 140                Hsieh T.-J., Hsiao H.-F., Yeh W.-C.  False     188.0
# 141                         [No author name available]  False       NaN
# 142                  Dunis C.L., Laws J., Sermpinis G.  False      12.0
# 143                  Zhai F., Lin X., Yang Z., Song Y.  False       9.0
#
#                                 DOI  \
# 0        10.1016/j.eswa.2019.112842
# 1        10.1016/j.eswa.2019.05.020
# 2      10.1016/j.inffus.2018.07.007
# 3                  10.1002/dac.3987
# 4      10.1016/j.knosys.2019.03.029
# 5          10.1109/TSP.2019.2907260
# 6         10.1109/TKDE.2018.2854193
# 7      10.1109/INFOMAN.2019.8714662
# 8       10.1109/ICASSP.2019.8682297
# 9        10.1109/AICAI.2019.8701258
# 10     10.1016/j.neucom.2019.01.092
# 11       10.1016/j.eswa.2018.11.027
# 12        10.1109/EBBT.2019.8741818
# 13     10.1109/ICCCBDA.2019.8725661
# 14     10.1109/BIGCOMP.2019.8679218
# 15       10.1109/ITNEC.2019.8729026
# 16    10.1109/ICA-SYMP.2019.8645980
# 17         10.1109/ICDMW.2018.00032
# 18            10.21314/JCF.2018.358
# 19          10.1109/DSAA.2018.00019
# 20        10.1109/SSCI.2018.8628641
# 21   10.1109/IBIGDELFT.2018.8625357
# 22     10.1109/BigData.2018.8622303
# 23         10.1109/ICMLA.2018.00227
# 24         10.1109/ICMLA.2018.00242
# 25     10.1016/j.knosys.2018.10.034
# 26         10.1109/BDCAT.2018.00027
# 27        10.1007/s00521-017-3039-z
# 28               10.3390/app9152980
# 29       10.1007/s13042-019-00994-7
# ..                              ...
# 114             10.1109/CBI.2017.23
# 115     10.1109/ICSSSM.2017.7996306
# 116           10.1109/CCBD.2016.027
# 117       10.1007/s10586-017-0803-x
# 118                            None
# 119       10.1007/978-3-319-68612-7
# 120       10.1007/978-3-319-68612-7
# 121    10.1007/978-3-319-63309-1_70
# 122    10.1007/978-3-319-60438-1_69
# 123               10.1002/isaf.1401
# 124       10.1109/ICIS.2016.7550882
# 125    10.1016/j.neucom.2015.01.109
# 126          10.1109/SYNASC.2015.49
# 127                            None
# 128            10.1155/2016/4742515
# 129         10.1145/2820426.2820467
# 130   10.1080/18756891.2015.1099910
# 131    10.1080/08839514.2014.923174
# 132                10.1002/for.2270
# 133       10.1016/j.rfe.2013.05.005
# 134  10.1016/j.engappai.2012.12.012
# 135       10.1007/s11227-012-0827-1
# 136     10.1007/978-1-4471-4866-1_9
# 137                            None
# 138                            None
# 139      10.1016/j.eswa.2010.09.037
# 140      10.1016/j.asoc.2010.09.007
# 141                            None
# 142       10.1080/13518470903037771
# 143       10.1109/ICNC.2010.5584802
#
#                            ...                         Page start  \
# 0                          ...                                NaN
# 1                          ...                               28.0
# 2                          ...                              120.0
# 3                          ...                                NaN
# 4                          ...                               68.0
# 5                          ...                             3001.0
# 6                          ...                             1094.0
# 7                          ...                              248.0
# 8                          ...                             7545.0
# 9                          ...                              228.0
# 10                         ...                                1.0
# 11                         ...                              197.0
# 12                         ...                                NaN
# 13                         ...                              321.0
# 14                         ...                                NaN
# 15                         ...                             1083.0
# 16                         ...                              119.0
# 17                         ...                              168.0
# 18                         ...                               73.0
# 19                         ...                               90.0
# 20                         ...                             1837.0
# 21                         ...                               92.0
# 22                         ...                             1397.0
# 23                         ...                             1394.0
# 24                         ...                             1486.0
# 25                         ...                              163.0
# 26                         ...                              160.0
# 27                         ...                              573.0
# 28                         ...                                NaN
# 29                         ...                                NaN
# ..                         ...                                ...
# 114                        ...                                7.0
# 115                        ...                                NaN
# 116                        ...                               87.0
# 117                        ...                              789.0
# 118                        ...                              681.0
# 119                        ...                              731.0
# 120                        ...                              729.0
# 121                        ...                              786.0
# 122                        ...                              708.0
# 123                        ...                                3.0
# 124                        ...                                NaN
# 125                        ...                               23.0
# 126                        ...                              261.0
# 127                        ...                              403.0
# 128                        ...                                NaN
# 129                        ...                              121.0
# 130                        ...                             1004.0
# 131                        ...                              597.0
# 132                        ...                              134.0
# 133                        ...                              213.0
# 134                        ...                             1562.0
# 135                        ...                              490.0
# 136                        ...                              125.0
# 137                        ...                             5559.0
# 138                        ...                              577.0
# 139                        ...                             3765.0
# 140                        ...                             2510.0
# 141                        ...                                NaN
# 142                        ...                              541.0
# 143                        ...                             3983.0
#
#                                             References SELECTED  Source  \
# 0    Bengio, Y., Frasconi, P., Input-output HMMs fo...     True  Scopus
# 1    Kim, K.-J., Financial time series forecasting ...     True  Scopus
# 2    Kamruzzaman, J., ANN-based forecasting of fore...     True  Scopus
# 3    Thakur, A., Tiwari, A., Kumar, S., Jain, A., S...     True  Scopus
# 4    Larochelle, H., Bengio, Y., Louradour, J., Lam...     True  Scopus
# 5    Arévalo, A., Niño, J., Hernández, G., Sandoval...     True  Scopus
# 6    Aït-Sahalia, Y., Jacod, J., Testing for jumps ...     True  Scopus
# 7    Abu-Mostafa, Y.S., Atiya, A.F., Introduction t...     True  Scopus
# 8    Aweya, J., (1999) Sensitivity Methods for Cong...     True  Scopus
# 9    Contreras, J., Rosario, E., Nogales, F.J., Con...     True  Scopus
# 10   Adya, M., Collopy, F., How effective are neura...     True  Scopus
# 11   Jasic, T., Wood, D., The profitability of dail...     True  Scopus
# 12   Samuelson, P., Proof that properly anticipated...     True  Scopus
# 13   Aussem, A., Murtagh, F., Combining neural netw...     True  Scopus
# 14   Borovykh, A., Bohte, S., Oosterlee, C., Condit...     True  Scopus
# 15   Abadi, M., Tensorflow: A system for large-scal...     True  Scopus
# 16   Fama, E., Efficient capital markets: A review ...     True  Scopus
# 17   Bollerslev, T., Engle, R., Nelson, D., Arch mo...     True  Scopus
# 18   Nonejad, N., Prediction aggregate stock market...     True  Scopus
# 19   Cao, L.J., Tay, F.E., Support vector machine w...     True  Scopus
# 20   Fama, E.F., Fisher, L., Jensen, M.C., Roll, R....     True  Scopus
# 21   Jiang, Z.-Q., Zhou, W.-X., Sornette, D., Wooda...     True  Scopus
# 22   Clerc, M., (2010) Particle Swarm Optimization,...     True  Scopus
# 23   Alonso-Martín, F., Castro-González, A., Luengo...     True  Scopus
# 24   Alessandretti, L., Elbahrawy, A., Aiello, L.M....     True  Scopus
# 25   Abe, M., Nakayama, H., Deep Learning for Forec...     True  Scopus
# 26   Bergstra, J., Algorithms for Hyper-Parameter O...     True  Scopus
# 27   (2017) Deep MNIST for experts, , https://www.t...     True  Scopus
# 28   Abadi, M., Barham, P., Chen, J., Chen, Z., Dav...     True  Scopus
# 29   Azirah, S.A., Hussin, B., Yusof, M., A data-dr...     True  Scopus
# ..                                                 ...      ...     ...
# 114  Maiorino, E., Bianchi, F.M., Livi, L., Rizzi, ...     True  Scopus
# 115  Copeland, T., Koller, T., Murrin, J., (1996) V...     True  Scopus
# 116  Poyser, O., Exploring the Determinants of Bitc...     True  Scopus
# 117  Taylor, G.W., (2009) Composable, distributed-s...     True  Scopus
# 118  Min, G., Hui, P., Xiaoyang, P., Xiaohong, C., ...     True  Scopus
# 119  Graham, B., Dodd, D.L., (1934) Security Analys...     True  Scopus
# 120  Meese, R.A., Rogoff, K., Empirical exchange ra...     True  Scopus
# 121  Gerasimo, M., Konstantions, P., Yannis, T., Ba...     True  Scopus
# 122  Wu, Z.-Y., Forecasting stock indexes based on ...     True  Scopus
# 123  Hodric, R.J., Prescott, E.C., Postwar U.S. bus...     True  Scopus
# 124  Hatcher, W.G., Yu, W., A survey of deep learni...     True  Scopus
# 125  Zhang, L., Wang, F., Bing, X., Chi, W., Wang, ...     True  Scopus
# 126  Atiya, A.F., Member, S., El-Shoura, S.M., Shah...     True  Scopus
# 127  Peters, E.E., (1994) Fractal Market Analysis: ...     True  Scopus
# 128  Adam, K., Marcet, A., Nicolini, J.P., Stock ma...     True  Scopus
# 129  Crone, S.F., Hibon, M., Nikolopoulos, K., Adva...     True  Scopus
# 130  Kietzmann, J.H., Hermkens, K., McCarthy, I.P.,...     True  Scopus
# 131  Barabási, A.-L., (2010) Bursts: The Hidden Pat...     True  Scopus
# 132  Pineda, F.J., Generalization of back-propagati...     True  Scopus
# 133  Dimson, E., Mussavian, M., A brief history of ...     True  Scopus
# 134  Zhang, G., Hu, M.Y., Neural network forecastin...     True  Scopus
# 135  Cao, Z., Zhu, Y., Improving prediction accurac...     True  Scopus
# 136  Breitner, M.H., Luedtke, C., Von Mettenheim, H...     True  Scopus
# 137                                               None     True  Scopus
# 138                                               None     True  Scopus
# 139                                               None     True  Scopus
# 140                                               None     True  Scopus
# 141                                               None     True  Scopus
# 142                                               None     True  Scopus
# 143                                               None     True  Scopus
#
#                                           Source title  \
# 0                     Expert Systems with Applications
# 1                     Expert Systems with Applications
# 2                                   Information Fusion
# 3       International Journal of Communication Systems
# 4                              Knowledge-Based Systems
# 5               IEEE Transactions on Signal Processing
# 6    IEEE Transactions on Knowledge and Data Engine...
# 7    5th International Conference on Information Ma...
# 8    ICASSP, IEEE International Conference on Acous...
# 9    Proceedings - 2019 Amity International Confere...
# 10                                      Neurocomputing
# 11                    Expert Systems with Applications
# 12   2019 Scientific Meeting on Electrical-Electron...
# 13   2019 IEEE 4th International Conference on Clou...
# 14   2019 IEEE International Conference on Big Data...
# 15   Proceedings of 2019 IEEE 3rd Information Techn...
# 16   2019 1st International Symposium on Instrument...
# 17   IEEE International Conference on Data Mining W...
# 18                    Journal of Computational Finance
# 19   Proceedings - 2018 IEEE 5th International Conf...
# 20   Proceedings of the 2018 IEEE Symposium Series ...
# 21   International Congress on Big Data, Deep Learn...
# 22   Proceedings - 2018 IEEE International Conferen...
# 23   Proceedings - 17th IEEE International Conferen...
# 24   Proceedings - 17th IEEE International Conferen...
# 25                             Knowledge-Based Systems
# 26   Proceedings - 5th IEEE/ACM International Confe...
# 27                   Neural Computing and Applications
# 28                      Applied Sciences (Switzerland)
# 29   International Journal of Machine Learning and ...
# ..                                                 ...
# 114  Proceedings - 2017 IEEE 19th Conference on Bus...
# 115  14th International Conference on Services Syst...
# 116  Proceedings - 2016 7th International Conferenc...
# 117                                  Cluster Computing
# 118  ICAART 2017 - Proceedings of the 9th Internati...
# 119  Lecture Notes in Computer Science (including s...
# 120  Lecture Notes in Computer Science (including s...
# 121  Lecture Notes in Computer Science (including s...
# 122  Lecture Notes in Computer Science (including s...
# 123  Intelligent Systems in Accounting, Finance and...
# 124  2016 IEEE/ACIS 15th International Conference o...
# 125                                     Neurocomputing
# 126  Proceedings - 17th International Symposium on ...
# 127  International Journal of Circuits, Systems and...
# 128        Computational Intelligence and Neuroscience
# 129  WebMedia 2015 - Proceedings of the 21st Brazil...
# 130  International Journal of Computational Intelli...
# 131                    Applied Artificial Intelligence
# 132                             Journal of Forecasting
# 133                      Review of Financial Economics
# 134  Engineering Applications of Artificial Intelli...
# 135                          Journal of Supercomputing
# 136      Advanced Information and Knowledge Processing
# 137  International Journal of Innovative Computing,...
# 138  Lecture Notes in Engineering and Computer Science
# 139                   Expert Systems with Applications
# 140                     Applied Soft Computing Journal
# 141  Proceedings of the 18th European Symposium on ...
# 142                        European Journal of Finance
# 143  Proceedings - 2010 6th International Conferenc...
#
#                                                  Title         Volume  Year  \
# 0    Improving DWT-RNN model via B-spline wavelet m...            138  2019
# 1    Direct marketing campaigns in retail banking w...            134  2019
# 2    Combining time-series and textual data for tax...             49  2019
# 3    Stock price forecasting model based on modifie...             32  2019
# 4               Sentiment-aware volatility forecasting            176  2019
# 5    DeepLOB: Deep convolutional neural networks fo...             67  2019
# 6    DeepClue: Visual interpretation of text-based ...             31  2019
# 7    Stock Price Prediction Based on Information En...           None  2019
# 8    Deep Temporal Logistic Bag-of-features for For...       2019-May  2019
# 9    Comparison of Predictive Algorithms: Backpropa...           None  2019
# 10   Energy futures prices forecasting by novel DPF...            338  2019
# 11   Lagged correlation-based deep learning for dir...            120  2019
# 12   Deep learning based forecasting in stock marke...           None  2019
# 13   Application of improved convolution neural net...           None  2019
# 14   CEAM: A Novel Approach Using Cycle Embeddings ...           None  2019
# 15   Forecasting stock prices in two ways based on ...           None  2019
# 16   Spatio-temporal Model for Limit Order Books in...           None  2019
# 17   A new forecasting framework for bitcoin price ...  2018-November  2019
# 18   Dilated convolutional neural networks for time...             22  2019
# 19   Multivariate time series early classification ...           None  2019
# 20   Hybrid Deep Learning Model for Stock Price Pre...           None  2019
# 21   Technical Analysis on Financial Time Series Da...           None  2019
# 22   Mining Illegal Insider Trading of Stocks: A Pr...           None  2019
# 23   A Comparison of ARIMA and LSTM in Forecasting ...           None  2019
# 24   Token-Based Adaptive Time-Series Prediction by...           None  2019
# 25   Deep learning-based feature engineering for st...            164  2019
# 26   Recurrent Embedding Kernel for Predicting Stoc...           None  2019
# 27   Research on exchange rate forecasting based on...             31  2019
# 28   An intelligent event-sentiment-based daily for...              9  2019
# 29   DeepCascade-WR: a cascading deep architecture ...           None  2019
# ..                                                 ...            ...   ...
# 114  Forecasting stock prices from the limit order ...              1  2017
# 115  Sentiment-aware stock market prediction: A dee...           None  2017
# 116  Financial time-series data analysis using deep...           None  2017
# 117  Model and forecast stock market behavior integ...             20  2017
# 118  Deep learning for predictions in emerging curr...              2  2017
# 119  A convolutional neural network based approach ...     10614 LNCS  2017
# 120  Conditional time series forecasting with convo...     10614 LNCS  2017
# 121  A three-step deep neural network methodology f...     10361 LNCS  2017
# 122  Predicting stock trends based on expert recomm...     10352 LNAI  2017
# 123  Modelling and trading the London, New York and...             24  2017
# 124  Deep learning for stock prediction using numer...           None  2016
# 125  Regularized dynamic self-organized neural netw...            188  2016
# 126  Forecasting Techniques for Time Series from Se...           None  2016
# 127  Artificial neural networks architectures for s...             10  2016
# 128  Financial Time Series Prediction Using Elman R...           2016  2016
# 129  The impact of structured event embeddings on s...           None  2015
# 130  Polynomial Based Functional Link Artificial Re...              8  2015
# 131  Evolving recurrent neural network using cartes...             28  2014
# 132  A neuro-wavelet model for the short-term forec...             33  2014
# 133  Irrational fads, short-term memory emulation, ...             22  2013
# 134  A hybrid intelligent model based on recurrent ...             26  2013
# 135  Forecasting large scale conditional volatility...             63  2013
# 136  Planning purchase decisions with advanced neur...           None  2013
# 137  A hybrid recurrent neural networks model based...              8  2012
# 138  A neuro-wavelet method for the forecasting of ...              1  2012
# 139  Dynamic Ridge Polynomial Neural Network: Forec...             38  2011
# 140  Forecasting stock markets using wavelet transf...             11  2011
# 141  18th European Symposium on Artificial Neural N...           None  2010
# 142  Modelling and trading the EUR/USD exchange rat...             16  2010
# 143  RETRACTED ARTICLE: Financial time series predi...              8  2010
#
#                                               keywords  \
# 0    Component trends;Empirical mode decomposition;...
# 1    Earnings;Financial data processing;Information...
# 2    Exchange rate time series;Bioinformatics;Excha...
# 3    Auto-regressive exogenous inputs;NARX algorith...
# 4    Commerce;Deep learning;Electronic trading;Fina...
# 5    High-frequency forecasting;Discrete wavelet tr...
# 6    Financial time series;Recurrent neural network...
# 7    Overfitting preventions;Medical data analysis;...
# 8    Complex networks;Data mining;Economics;Forecas...
# 9    MAPE;Financial data processing;Electronic trad...
# 10   Machine learning;Neural networks;Stock predict...
# 11   Recurrent Neural Network;Principal Component A...
# 12   Statistical modeling;Financial forecasting;For...
# 13   Convolutional neural network (CNN);Deep learni...
# 14   Long-term dependencies;Finance;Forecasting;Mul...
# 15   Deep Learning;Aleatoric models;Forecasting;Dee...
# 16   Expert recommendations;Time series prediction;...
# 17   GPU;Financial data processing;Conditional rest...
# 18   Forecasting;Support vector machines;stock pred...
# 19   Time series analysis;Financial time series;Dec...
# 20   Social networking (online);Time series predict...
# 21   Embedding Method;LSTM;Market Prediction;Market...
# 22   Time series analysis;Information retrieval;Sen...
# 23   Artificial intelligence;Artificial intelligenc...
# 24   Multi-step;Volatility forecasting;Dimensionali...
# 25   Artificial intelligence;Statistical forecastin...
# 26   Deep Learning;Artificial neural networks;Time ...
# 27   Data science;Deep learning;Fintech;Machine lea...
# 28   Correlation theory;High-frequency trading;Fore...
# 29   Convolutional neural networks;Research and app...
# ..                                                 ...
# 114  Financial time series;Information use;Electron...
# 115  Accounts receivable;ARIMA;Cash flow prediction...
# 116  Forecasting accuracy;Financial time series;Fin...
# 117  Generalization ability;Time series prediction;...
# 118  Financial time series;Biological vision system...
# 119  Trend forecast;Data handling;Forecasting;Proce...
# 120  Deep learning;Event sentiment;Forecasting;Fore...
# 121  Information theory;Investment strategy;LSTM;In...
# 122  Stock data;Forecasting;Similar Stock;CART;Slid...
# 123  Stock forecasting;High-frequency trading;Forec...
# 124  Semantics;Attention mechanisms;Stock price pre...
# 125  Long and short term memory;Phase space reconst...
# 126  Economics;Finance;Genetic algorithms;Genetic p...
# 127  Filter noise;Time series analysis;Financial ti...
# 128  Change patterns;Long-term dependencies;Deep le...
# 129  Feature representation;Knowledge acquisition;T...
# 130  Information theory;Finance;Forecasting;Social ...
# 131  Fusion methods;Forecasting;Representative patt...
# 132  Time-dependent characteristics;Recurrent neura...
# 133  Stock trend prediction;Forecasting;stock;LSTM;...
# 134  Exchange rate forecasting;Exchange rates;Finan...
# 135  Curse of dimensionality;Chemical detection;Clu...
# 136  CNN;CNNs;ann;costs;financial time series;forec...
# 137  artificial intelligence;artificial neural netw...
# 138  LSTM;algorithm;algorithms;anomaly detection;cl...
# 139  Classification Methods;Commerce;Deep Learning;...
# 140  Classification Methods;Commerce;Deep Learning;...
# 141  Artificial Neural Network;Artificial Neural Ne...
# 142  algorithm;article;autoencoder;cluster;feedforw...
# 143  ARTICLE;Artificial Neural Network;Artificial N...
#
#                                     keywords (cleaned)
# 0    trends;Nonlinear autoregressive neural network...
# 1    Novel applications;Earnings;Tokyo Stock Exchan...
# 2    Self-organized neural networks;financial time ...
# 3    Financial applications;Financial markets;forec...
# 4    Financial markets;forecasting accuracy;Histori...
# 5    Topology;forecasting accuracy;forecasting;Sign...
# 6    stock markets;forecasting;trading;Threshold pa...
# 7    Financial markets;forecasting;investments;deep...
# 8    Multi-step ahead forecast;economics;forecastin...
# 9    polynomials;forecasting;PFLARNN;trading;Evolut...
# 10   artificial neural networks;machine learning;st...
# 11   Financial markets;forecasting;time series;cost...
# 12   Financial markets;Performance analysis;forecas...
# 13   multivariate time series;forecasting;convoluti...
# 14   multivariate time series;Long-term dependencie...
# 15   Uncertainty;Learning models;forecasting;time s...
# 16   Financial markets;forecasting;artificial neura...
# 17   forecasting;Multicore architectures;Computer s...
# 18   Structural parameter;Financial markets;forecas...
# 19   Cloud computing;trading;convolution;Learning a...
# 20   Financial markets;forecasting accuracy;forecas...
# 21   Market Vector;technical indicator;long short-t...
# 22   forecasting;Pre-processing stages;Information ...
# 23   Financial managements;Financial industry;inves...
# 24   Multi-step ahead forecast;multivariate time se...
# 25   Multitask learning;forecasting;Statistical for...
# 26   Financial markets;forecasting;financial time s...
# 27   stock markets;deep learning;Data science;Finte...
# 28   Financial markets;forecasting;Correlation theo...
# 29   Energy industry;Numerical methods;convolutiona...
# ..                                                 ...
# 114  Financial markets;forecasting;convolutional ne...
# 115  artificial neural networks;Prophet;feedforward...
# 116  forecasting accuracy;forecasting;Correlation t...
# 117  Decomposition and reconstruction;forecasting;f...
# 118  feature extraction;Cloud computing;forecasting...
# 119  Financial markets;trends;forecasting;time seri...
# 120  forecasting;regression;deep learning;exchange ...
# 121  Temporal dynamics;Financial markets;investment...
# 122  Financial markets;CART;forecasting;slide windo...
# 123  Statistical tests;economics;forecasting;convol...
# 124  Financial markets;forecasting accuracy;forecas...
# 125  Financial markets;forecasting accuracy;Phase s...
# 126  genetic algorithms;forecasting accuracy;Perfor...
# 127  Filter noise;forecasting;time series forecasti...
# 128  Financial markets;Long-term dependencies;forec...
# 129  Weak results;forecasting accuracy;Feature repr...
# 130  Statistical tests;Financial markets;forecastin...
# 131  fusion methods;Financial markets;forecasting a...
# 132  Financial markets;convolutional neural network...
# 133  Financial markets;forecasting accuracy;forecas...
# 134  DBN;forecasting;Variance analysis;deep learnin...
# 135  forecasting;Speech recognition;Clustering algo...
# 136  forecasting;convolutional neural network;inves...
# 137  stock markets;forecasting;price forecasting;me...
# 138  forecasting;regression;simulation;time series;...
# 139  forecasting;commerce;transaction;artificial ne...
# 140  stock markets;forecasting;Classifiers;deep lea...
# 141  commerce;transaction;artificial neural network...
# 142  random forest;financial time series forecastin...
# 143  forecasting;regression;learning techniques;ext...
#
# [144 rows x 27 columns]

# %% [markdown]
# ## Title

# %%
doc_normalizer = DocNormalizer()

# %%
doc_normalizer.fit(rdf['Title'])
# Out:
# Loaded 326 stopwords
# DocNormalizer(words_keep=None)

# %% [markdown]
# #### Stop words loaded to clean text

# %%
doc_normalizer.stopwords_[:10]
# Out:
# ['through',
#  'thereafter',
#  'too',
#  '‘ll',
#  '’m',
#  '’ve',
#  'hereupon',
#  'six',
#  'of',
#  'itself']

# %% [markdown]
# #### Document cleansing - Title

# %%
docs_normalized = doc_normalizer.transform(rdf['Title'])
# Out:
# Normalizing documents

# %%
print('Fisrt document before the process of normalization\n')
print(rdf.loc[0,'Title'], '\n')
# Out:
# Fisrt document before the process of normalization
#
# Improving DWT-RNN model via B-spline wavelet multiresolution to forecast a high-frequency time series

# %%
print('Fisrt document after the process of normalization\n')
print(docs_normalized[0], '\n')
# Out:
# Fisrt document after the process of normalization
#
# improve dwtrnn model via bspline wavelet multiresolution to forecast a highfrequency time series

# %% [markdown]
# #### For the whole corpus of titles

# %%
corpus = list(rdf.loc[:,'Title'].values)
vocabulary = [word for doc in corpus for word in doc.split()]

# %%
print(f'Number of words in the corpus: {len(vocabulary)}')
print(f'Number of words in the vocabulary of the corpus: {len(set(vocabulary))}')
# Out:
# Number of words in the corpus: 1654
# Number of words in the vocabulary of the corpus: 579

# %%
vocabulary_cleaned = [word for doc in docs_normalized for word in doc.split()]

# %%
print(f'Number of words in the corpus: {len(vocabulary_cleaned)}')
print(f'Number of words in the vocabulary of the corpus: {len(set(vocabulary_cleaned))}')
# Out:
# Number of words in the corpus: 1652
# Number of words in the vocabulary of the corpus: 443

# %%
print(f'Reduction of {round(1 - len(vocabulary_cleaned)/len(vocabulary),4)*100}% from the total number of words in the corpus')
print(f'Reduction of {round(1 - len(set(vocabulary_cleaned))/len(set(vocabulary)),3)*100}% from the uncleaned vocabulary')
# Out:
# Reduction of 0.12% from the total number of words in the corpus
# Reduction of 23.5% from the uncleaned vocabulary

# %% [markdown]
# ## Abstract

# %%
doc_normalizer = DocNormalizer()

# %%
doc_normalizer.fit(rdf['Abstract'])
# Out:
# Loaded 326 stopwords
# DocNormalizer(words_keep=None)

# %% [markdown]
# #### Document cleansing - Abstract

# %%
docs_normalized = doc_normalizer.transform(rdf['Abstract'])
# Out:
# Normalizing documents

# %%
print('Fisrt document before the process of normalization\n')
print(rdf.iloc[0,0], '\n')
# Out:
# Fisrt document before the process of normalization
#
# The importance of an interference-less machine learning scheme in time series prediction is crucial, as an oversight can have a negative cumulative effect, especially when predicting many steps ahead of the currently available data. The on-going research on noise elimination in time series forecasting has led to a successful approach of decomposing the data sequence into component trends to identify noise-inducing information. The empirical mode decomposition method separates the time series/signal into a set of intrinsic mode functions ranging from high to low frequencies, which can be summed up to reconstruct the original data. The usual assumption that random noises are only contained in the high-frequency component has been shown not to be the case, as observed in our previous findings. The results from that experiment reveal that noise can be present in a low frequency component, and this motivates the newly-proposed algorithm. Additionally, to prevent the erosion of periodic trends and patterns within the series, we perform the learning of local and global trends separately in a hierarchical manner which succeeds in detecting and eliminating short/long term noise. The algorithm is tested on four datasets from financial market data and physical science data. The simulation results are compared with the conventional and state-of-the-art approaches for time series machine learning, such as the non-linear autoregressive neural network and the long short-term memory recurrent neural network, respectively. Statistically significant performance gains are recorded when the meta-learning algorithm for noise reduction is used in combination with these artificial neural networks. For time series data which cannot be decomposed into meaningful trends, applying the moving average method to create meta-information for guiding the learning process is still better than the traditional approach. Therefore, this new approach is applicable to the forecasting of time series with a low signal to noise ratio, with a potential to scale adequately in a multi-cluster system due to the parallelized nature of the algorithm.

# %%
print('Fisrt document after the process of normalization\n')
print(docs_normalized[0], '\n')
# Out:
# Fisrt document after the process of normalization
#
# the importance of an interferenceless machine learn scheme in time series prediction be crucial as an oversight can have a negative cumulative effect especially when predict many step ahead of the currently available datum the ongoing research on noise elimination in time series forecasting have lead to a successful approach of decompose the data sequence into component trend to identify noiseinduce information the empirical mode decomposition method separate the time series signal into a set of intrinsic mode function range from high to low frequency which can be sum up to reconstruct the original datum the usual assumption that random noise be only contain in the highfrequency component have be show not to be the case as observe in previous finding the result from that experiment reveal that noise can be present in a low frequency component and this motivate the newlyproposed algorithm additionally to prevent the erosion of periodic trend and pattern within the series perform the learning of local and global trend separately in a hierarchical manner which succeed in detect and eliminate short long term noise the algorithm be test on four dataset from financial market datum and physical science datum the simulation result be compare with the conventional and stateoftheart approach for time series machine learn such as the nonlinear autoregressive neural network and the long shortterm memory recurrent neural network respectively statistically significant performance gain be record when the metalearning algorithm for noise reduction be use in combination with these artificial neural network for time series datum which can not be decompose into meaningful trend apply the move average method to create metainformation for guide the learning process be still well than the traditional approach therefore this new approach be applicable to the forecasting of time series with a low signal to noise ratio with a potential to scale adequately in a multicluster system due to the parallelize nature of the algorithm

# %% [markdown]
# #### For the whole corpus of documents

# %%
corpus = list(rdf.iloc[:,0].values)
vocabulary = [word for doc in corpus for word in doc.split()]

# %%
print(f'Number of words in the corpus: {len(vocabulary)}')
print(f'Number of words in the vocabulary of the corpus: {len(set(vocabulary))}')
# Out:
# Number of words in the corpus: 25473
# Number of words in the vocabulary of the corpus: 4920

# %%
vocabulary_cleaned = [word for doc in docs_normalized for word in doc.split()]

# %%
print(f'Number of words in the corpus: {len(vocabulary_cleaned)}')
print(f'Number of words in the vocabulary of the corpus: {len(set(vocabulary_cleaned))}')
# Out:
# Number of words in the corpus: 24900
# Number of words in the vocabulary of the corpus: 2746

# %%
print(f'Reduction of {round(1 - len(vocabulary_cleaned)/len(vocabulary),4)*100}% from the total number of words in the corpus')
print(f'Reduction of {round(1 - len(set(vocabulary_cleaned))/len(set(vocabulary)),3)*100}% from the uncleaned vocabulary')
# Out:
# Reduction of 2.25% from the total number of words in the corpus
# Reduction of 44.2% from the uncleaned vocabulary
