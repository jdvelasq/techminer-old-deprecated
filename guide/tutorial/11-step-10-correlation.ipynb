# %% [markdown]
# # Step 10: Cross-correlation

# %%
import pandas as pd
from techminer import RecordsDataFrame

rdf = RecordsDataFrame(
    pd.read_json(
        'step-06.json', 
        orient='records', 
        lines=True))

# %% [markdown]
# In this part, a second level analysis of the bibliographical information is done.

# %% [markdown]
# ## Autocorrelation

# %%
rdf.autocorrelation(
    term='keywords (cleaned)',
    sep=';'
).to_matrix().head()
# Out:
#                            Algorithmic trading  Algorithms  \
# Algorithmic trading                   1.000000    0.378895
# Algorithms                            0.378895    1.000000
# Artificial intelligence               0.170973    0.111803
# Automated trading                     0.041957    0.112032
# Automated trading systems             0.065539    0.050000
#
#                            Artificial intelligence  Automated trading  \
# Algorithmic trading                       0.170973           0.041957
# Algorithms                                0.111803           0.112032
# Artificial intelligence                   1.000000           0.229039
# Automated trading                         0.229039           1.000000
# Automated trading systems                 0.089443           0.128037
#
#                            Automated trading systems  Automation  Commerce  \
# Algorithmic trading                         0.065539    0.059828  0.381461
# Algorithms                                  0.050000    0.045644  0.249446
# Artificial intelligence                     0.089443    0.163299  0.386727
# Automated trading                           0.128037    0.397396  0.323642
# Automated trading systems                   1.000000    0.365148  0.292684
#
#                               Costs  Data mining  Electronic trading  \
# Algorithmic trading        0.131182     0.121702            0.335960
# Algorithms                 0.160128     0.162483            0.117474
# Artificial intelligence    0.214834     0.193773            0.331136
# Automated trading          0.102512     0.213983            0.109389
# Automated trading systems  0.000000     0.074278            0.119610
#
#                             Finance  Financial data processing  \
# Algorithmic trading        0.188805                   0.169105
# Algorithms                 0.240069                   0.202733
# Artificial intelligence    0.248126                   0.219793
# Automated trading          0.213115                   0.151024
# Automated trading systems  0.051215                   0.088465
#
#                            Financial markets  Forecasting  High frequency  \
# Algorithmic trading                 0.250838     0.095577        0.094277
# Algorithms                          0.229640     0.062500        0.246598
# Artificial intelligence             0.258647     0.074536        0.024507
# Automated trading                   0.182948     0.149376        0.042098
# Automated trading systems           0.163299     0.133333        0.000000
#
#                            High-frequency trading  Investments  Profitability  \
# Algorithmic trading                      0.150797     0.159050       0.212635
# Algorithms                               0.201328     0.208013       0.141944
# Artificial intelligence                  0.137199     0.144707       0.145095
# Automated trading                        0.019640     0.177555       0.166163
# Automated trading systems                0.015339     0.138675       0.129777
#
#                            Trading strategies   trading
# Algorithmic trading                  0.209957  0.150193
# Algorithms                           0.169600  0.437500
# Artificial intelligence              0.157313  0.000000
# Automated trading                    0.115814  0.064018
# Automated trading systems            0.120605  0.000000

# %%
rdf.autocorrelation(
    term='keywords (cleaned)',
    sep=';'
).circleplot_in_altair()
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
rdf.autocorrelation(
    term='keywords (cleaned)',
    sep=';').heatmap()

# %%
rdf.autocorrelation(
    term='keywords (cleaned)',
    sep=';').radial_plot(minval=0.4)

# %% [markdown]
# ## Crosscorrelation

# %%
rdf.crosscorrelation(
    termA='keywords (cleaned)',
    sepA=';',
    termB='Authors',
    sepB=','
).head(10)
# Out:
#     keywords (cleaned)         Authors  Crosscorrelation
# 0  Algorithmic trading       Cartea Á.          0.163846
# 1  Algorithmic trading        Cliff D.          0.000000
# 2  Algorithmic trading     Debenham J.          0.000000
# 3  Algorithmic trading      Gabbouj M.          0.000000
# 4  Algorithmic trading       Hudson R.          0.000000
# 5  Algorithmic trading    Iosifidis A.          0.000000
# 6  Algorithmic trading  Jacobsen H.-A.          0.000000
# 7  Algorithmic trading    Jaimungal S.          0.000000
# 8  Algorithmic trading   Kompella R.R.          0.000000
# 9  Algorithmic trading          Luk W.          0.000000

# %%
rdf.crosscorrelation(
    termA='keywords (cleaned)',
    sepA=';',
    termB='Authors',
    sepB=','
).heatmap()

# %%
rdf.crosscorrelation(
    termA='keywords (cleaned)',
    sepA=';',
    termB='Authors',
    sepB=','
).to_matrix()
# Out:
#                            Cartea Á.  Cliff D.  Debenham J.  Gabbouj M.  \
# Algorithmic trading         0.163846  0.000000     0.000000    0.000000
# Algorithms                  0.000000  0.000000     0.000000    0.000000
# Artificial intelligence     0.000000  0.000000     0.000000    0.000000
# Automated trading           0.000000  0.128037     0.209083    0.209083
# Automated trading systems   0.000000  0.200000     0.000000    0.000000
# Automation                  0.000000  0.182574     0.149071    0.149071
# Commerce                    0.000000  0.066519     0.000000    0.000000
# Costs                       0.000000  0.000000     0.000000    0.000000
# Data mining                 0.000000  0.000000     0.379049    0.379049
# Electronic trading          0.000000  0.000000     0.000000    0.000000
# Finance                     0.000000  0.000000     0.000000    0.000000
# Financial data processing   0.000000  0.000000     0.000000    0.000000
# Financial markets           0.000000  0.102062     0.000000    0.000000
# Forecasting                 0.000000  0.000000     0.000000    0.000000
# High frequency              0.000000  0.000000     0.000000    0.000000
# High-frequency trading      0.076696  0.000000     0.000000    0.000000
# Investments                 0.000000  0.000000     0.000000    0.000000
# Profitability               0.000000  0.000000     0.000000    0.000000
# Trading strategies          0.000000  0.000000     0.000000    0.000000
# trading                     0.000000  0.000000     0.000000    0.000000
#
#                            Hudson R.  Iosifidis A.  Jacobsen H.-A.  \
# Algorithmic trading         0.000000      0.000000        0.000000
# Algorithms                  0.000000      0.000000        0.000000
# Artificial intelligence     0.000000      0.000000        0.000000
# Automated trading           0.000000      0.000000        0.000000
# Automated trading systems   0.000000      0.000000        0.000000
# Automation                  0.000000      0.000000        0.000000
# Commerce                    0.000000      0.000000        0.000000
# Costs                       0.000000      0.000000        0.000000
# Data mining                 0.000000      0.000000        0.000000
# Electronic trading          0.000000      0.000000        0.000000
# Finance                     0.000000      0.000000        0.000000
# Financial data processing   0.000000      0.000000        0.000000
# Financial markets           0.000000      0.000000        0.000000
# Forecasting                 0.000000      0.000000        0.000000
# High frequency              0.000000      0.000000        0.000000
# High-frequency trading      0.076696      0.076696        0.076696
# Investments                 0.000000      0.000000        0.000000
# Profitability               0.000000      0.000000        0.000000
# Trading strategies          0.000000      0.000000        0.000000
# trading                     0.000000      0.000000        0.000000
#
#                            Jaimungal S.  Kompella R.R.    Luk W.  Manahov V.  \
# Algorithmic trading            0.000000       0.000000  0.000000    0.123856
# Algorithms                     0.000000       0.000000  0.000000    0.000000
# Artificial intelligence        0.000000       0.000000  0.000000    0.056344
# Automated trading              0.000000       0.128037  0.128037    0.000000
# Automated trading systems      0.000000       0.000000  0.000000    0.000000
# Automation                     0.000000       0.000000  0.000000    0.000000
# Commerce                       0.000000       0.000000  0.000000    0.000000
# Costs                          0.000000       0.000000  0.000000    0.000000
# Data mining                    0.000000       0.000000  0.000000    0.000000
# Electronic trading             0.000000       0.000000  0.000000    0.000000
# Finance                        0.000000       0.000000  0.000000    0.000000
# Financial data processing      0.000000       0.000000  0.000000    0.000000
# Financial markets              0.000000       0.000000  0.000000    0.077152
# Forecasting                    0.000000       0.000000  0.000000    0.000000
# High frequency                 0.000000       0.000000  0.000000    0.000000
# High-frequency trading         0.076696       0.000000  0.000000    0.173931
# Investments                    0.000000       0.000000  0.000000    0.000000
# Profitability                  0.000000       0.000000  0.000000    0.061314
# Trading strategies             0.000000       0.000000  0.000000    0.000000
# trading                        0.000000       0.000000  0.000000    0.000000
#
#                            Maringer D.  Masteika S.   Ng W.L.  Raudys A.  \
# Algorithmic trading           0.000000     0.000000  0.000000   0.094597
# Algorithms                    0.088388     0.088388  0.088388   0.000000
# Artificial intelligence       0.000000     0.000000  0.000000   0.000000
# Automated trading             0.181071     0.181071  0.181071   0.000000
# Automated trading systems     0.000000     0.000000  0.000000   0.230940
# Automation                    0.129099     0.129099  0.129099   0.105409
# Commerce                      0.047036     0.047036  0.047036   0.076810
# Costs                         0.113228     0.113228  0.113228   0.000000
# Data mining                   0.000000     0.000000  0.000000   0.000000
# Electronic trading            0.000000     0.000000  0.000000   0.049326
# Finance                       0.090536     0.090536  0.090536   0.000000
# Financial data processing     0.104257     0.104257  0.104257   0.000000
# Financial markets             0.000000     0.000000  0.000000   0.058926
# Forecasting                   0.000000     0.000000  0.000000   0.000000
# High frequency                0.000000     0.000000  0.000000   0.000000
# High-frequency trading        0.000000     0.000000  0.000000   0.000000
# Investments                   0.098058     0.098058  0.098058   0.000000
# Profitability                 0.000000     0.000000  0.000000   0.000000
# Trading strategies            0.106600     0.106600  0.106600   0.000000
# trading                       0.117851     0.117851  0.117851   0.000000
#
#                            Sadoghi M.  Singh H.  Vaitonis M.  Zhang G.  \
# Algorithmic trading          0.183186  0.183186     0.047298  0.000000
# Algorithms                   0.111803  0.111803     0.000000  0.000000
# Artificial intelligence      0.000000  0.000000     0.000000  0.000000
# Automated trading            0.000000  0.000000     0.000000  0.000000
# Automated trading systems    0.000000  0.000000     0.000000  0.000000
# Automation                   0.000000  0.000000     0.000000  0.000000
# Commerce                     0.029748  0.029748     0.115214  0.047036
# Costs                        0.000000  0.000000     0.092450  0.000000
# Data mining                  0.000000  0.000000     0.000000  0.000000
# Electronic trading           0.000000  0.000000     0.147979  0.000000
# Finance                      0.000000  0.000000     0.000000  0.000000
# Financial data processing    0.065938  0.065938     0.000000  0.000000
# Financial markets            0.000000  0.000000     0.117851  0.000000
# Forecasting                  0.000000  0.000000     0.000000  0.000000
# High frequency               0.000000  0.000000     0.000000  0.000000
# High-frequency trading       0.000000  0.000000     0.132842  0.000000
# Investments                  0.000000  0.000000     0.000000  0.000000
# Profitability                0.000000  0.000000     0.093659  0.000000
# Trading strategies           0.000000  0.000000     0.174078  0.106600
# trading                      0.000000  0.000000     0.000000  0.000000
#
#                            Zhang H.
# Algorithmic trading        0.000000
# Algorithms                 0.000000
# Artificial intelligence    0.000000
# Automated trading          0.000000
# Automated trading systems  0.000000
# Automation                 0.000000
# Commerce                   0.047036
# Costs                      0.000000
# Data mining                0.000000
# Electronic trading         0.000000
# Finance                    0.000000
# Financial data processing  0.000000
# Financial markets          0.000000
# Forecasting                0.000000
# High frequency             0.000000
# High-frequency trading     0.000000
# Investments                0.000000
# Profitability              0.000000
# Trading strategies         0.106600
# trading                    0.000000

# %%
rdf.crosscorrelation(
    termA='keywords (cleaned)',
    sepA=';',
    termB='Authors',
    sepB=','
).cross_relation_plot()

# %% [markdown]
# ## Factor analysis

# %%
rdf.factor(
    term='keywords (cleaned)', 
    sep=';', 
    n_components=5, 
    N=40).head()
# Out:
#                                  F0        F1        F2        F3        F4
# Algorithmic trading       -0.039229 -0.558604  0.540784 -0.341773 -0.069914
# Algorithms                -0.056095 -0.075906  0.376717  0.313954  0.113379
# Artificial intelligence    0.154420 -0.045401 -0.021792  0.073288 -0.046595
# Automated trading          0.041562 -0.114313 -0.320929  0.398871  0.062725
# Automated trading systems  0.049255 -0.048811 -0.085604  0.071760 -0.067751

# %%
rdf.factor(
    term='keywords (cleaned)', 
    sep=';', 
    n_components=5, 
    N=40).heatmap()
