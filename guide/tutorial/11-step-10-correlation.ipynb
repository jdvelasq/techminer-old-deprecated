# %% [markdown]
# # Step 10: Cross-correlation

# %%
import pandas as pd
from techminer import RecordsDataFrame

rdf = RecordsDataFrame(
    pd.read_json(
        'step-06.json', 
        orient='records', 
        lines=True))

# %% [markdown]
# In this part, a second level analysis of the bibliographical information is done.

# %% [markdown]
# ## Autocorrelation

# %%
rdf.autocorrelation(
    term='keywords (cleaned)',
    sep=';'
).tomatrix().head()
# Out:
#                          Commerce  Artificial intelligence  \
# Commerce                 1.000000                 0.386727
# Artificial intelligence  0.386727                 1.000000
# Electronic trading       0.670606                 0.331136
# Financial markets        0.515969                 0.258647
# Algorithms               0.249446                 0.111803
#
#                          Electronic trading  Financial markets  Algorithms  \
# Commerce                           0.670606           0.515969    0.249446
# Artificial intelligence            0.331136           0.258647    0.111803
# Electronic trading                 1.000000           0.558064    0.117474
# Financial markets                  0.558064           1.000000    0.229640
# Algorithms                         0.117474           0.229640    1.000000
#
#                          Automated trading   Finance  Investments   trading  \
# Commerce                          0.323642  0.417327     0.396655  0.055433
# Artificial intelligence           0.229039  0.248126     0.144707  0.000000
# Electronic trading                0.109389  0.328168     0.308043  0.056957
# Financial markets                 0.182948  0.392031     0.283069  0.102062
# Algorithms                        0.112032  0.240069     0.208013  0.437500
#
#                          Trading strategies  High-frequency trading  \
# Commerce                           0.320900                0.413244
# Artificial intelligence            0.157313                0.137199
# Electronic trading                 0.270478                0.419368
# Financial markets                  0.246183                0.305284
# Algorithms                         0.169600                0.201328
#
#                          Financial data processing  Profitability     Costs  \
# Commerce                                  0.382500       0.312933  0.308895
# Artificial intelligence                   0.219793       0.145095  0.214834
# Electronic trading                        0.277130       0.207893  0.246252
# Financial markets                         0.270868       0.231793  0.147087
# Algorithms                                0.202733       0.141944  0.160128
#
#                          High frequency  Forecasting  Automation  Data mining  \
# Commerce                       0.142164     0.332595    0.279327     0.222341
# Artificial intelligence        0.024507     0.074536    0.163299     0.193773
# Electronic trading             0.028091     0.313264    0.109189     0.190380
# Financial markets              0.083895     0.289176    0.149071     0.189525
# Algorithms                     0.246598     0.062500    0.045644     0.162483
#
#                          Algorithmic trading  Automated trading systems
# Commerce                            0.381461                   0.292684
# Artificial intelligence             0.170973                   0.089443
# Electronic trading                  0.335960                   0.119610
# Financial markets                   0.250838                   0.163299
# Algorithms                          0.378895                   0.050000

# %%
rdf.autocorrelation(
    term='keywords (cleaned)',
    sep=';'
).circlerel()
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
rdf.autocorrelation(
    term='keywords (cleaned)',
    sep=';').heatmap()

# %%
rdf.autocorrelation(
    term='keywords (cleaned)',
    sep=';').chord_diagram(minval=0.4)

# %% [markdown]
# ## Crosscorrelation

# %%
rdf.crosscorrelation(
    termA='keywords (cleaned)',
    sepA=';',
    termB='Authors',
    sepB=','
).head(10)
# Out:
#     keywords (cleaned)         Authors  Crosscorrelation
# 0          Data mining     Debenham J.          0.350931
# 1    Automated trading        Cliff D.          0.256074
# 2          Forecasting    Iosifidis A.          0.250000
# 3          Forecasting      Gabbouj M.          0.250000
# 4    Automated trading     Debenham J.          0.241967
# 5  Algorithmic trading  Jacobsen H.-A.          0.216748
# 6  Algorithmic trading      Sadoghi M.          0.216748
# 7   Trading strategies         Ng W.L.          0.202260
# 8          Investments       Raudys A.          0.196116
# 9           Automation        Cliff D.          0.182574

# %%
rdf.crosscorrelation(
    termA='keywords (cleaned)',
    sepA=';',
    termB='Authors',
    sepB=','
).heatmap()

# %%
rdf.crosscorrelation(
    termA='keywords (cleaned)',
    sepA=';',
    termB='Authors',
    sepB=','
).tomatrix()
# Out:
#                            Debenham J.  Cliff D.  Iosifidis A.  Gabbouj M.  \
# Data mining                   0.350931  0.092848      0.000000    0.000000
# Automated trading             0.241967  0.256074      0.000000    0.000000
# Forecasting                   0.000000  0.083333      0.250000    0.250000
# Algorithmic trading           0.000000  0.000000      0.000000    0.000000
# Trading strategies            0.000000  0.000000      0.000000    0.000000
# Investments                   0.000000  0.000000      0.000000    0.000000
# Automation                    0.138013  0.182574      0.091287    0.091287
# High-frequency trading        0.000000  0.000000      0.115045    0.115045
# Electronic trading            0.000000  0.085436      0.170872    0.170872
# Financial data processing     0.000000  0.073721      0.000000    0.000000
# Financial markets             0.000000  0.153093      0.102062    0.102062
# trading                       0.000000  0.000000      0.000000    0.000000
# Artificial intelligence       0.000000  0.149071      0.074536    0.074536
# High frequency                0.000000  0.000000      0.000000    0.000000
# Profitability                 0.000000  0.000000      0.000000    0.000000
# Costs                         0.000000  0.080064      0.080064    0.080064
# Automated trading systems     0.000000  0.100000      0.000000    0.000000
# Commerce                      0.000000  0.133038      0.099779    0.099779
# Finance                       0.000000  0.064018      0.064018    0.064018
# Algorithms                    0.000000  0.000000      0.000000    0.000000
#
#                            Jacobsen H.-A.  Sadoghi M.   Ng W.L.  Raudys A.  \
# Data mining                      0.000000    0.000000  0.000000   0.065653
# Automated trading                0.000000    0.000000  0.000000   0.181071
# Forecasting                      0.000000    0.000000  0.074536   0.000000
# Algorithmic trading              0.216748    0.216748  0.073274   0.086893
# Trading strategies               0.000000    0.000000  0.202260   0.000000
# Investments                      0.000000    0.000000  0.000000   0.196116
# Automation                       0.000000    0.000000  0.000000   0.129099
# High-frequency trading           0.000000    0.000000  0.068599   0.054233
# Electronic trading               0.000000    0.000000  0.038208   0.030206
# Financial data processing        0.055728    0.055728  0.000000   0.156386
# Financial markets                0.000000    0.000000  0.045644   0.036084
# trading                          0.000000    0.000000  0.149071   0.000000
# Artificial intelligence          0.000000    0.000000  0.066667   0.052705
# High frequency                   0.000000    0.000000  0.147043   0.116248
# Profitability                    0.000000    0.000000  0.145095   0.114708
# Costs                            0.000000    0.000000  0.071611   0.000000
# Automated trading systems        0.000000    0.000000  0.000000   0.141421
# Commerce                         0.025142    0.025142  0.089245   0.117590
# Finance                          0.000000    0.000000  0.000000   0.000000
# Algorithms                       0.094491    0.094491  0.055902   0.044194
#
#                            Manahov V.  Cartea Á.  Jaimungal S.  Singh H.  \
# Data mining                  0.000000   0.000000      0.000000  0.000000
# Automated trading            0.000000   0.000000      0.000000  0.000000
# Forecasting                  0.000000   0.000000      0.000000  0.000000
# Algorithmic trading          0.123856   0.163846      0.163846  0.163846
# Trading strategies           0.000000   0.000000      0.000000  0.000000
# Investments                  0.000000   0.000000      0.000000  0.000000
# Automation                   0.000000   0.000000      0.000000  0.000000
# High-frequency trading       0.173931   0.076696      0.076696  0.000000
# Electronic trading           0.000000   0.000000      0.000000  0.000000
# Financial data processing    0.000000   0.000000      0.000000  0.073721
# Financial markets            0.077152   0.000000      0.000000  0.000000
# trading                      0.000000   0.000000      0.000000  0.000000
# Artificial intelligence      0.056344   0.000000      0.000000  0.000000
# High frequency               0.000000   0.000000      0.000000  0.000000
# Profitability                0.061314   0.000000      0.000000  0.000000
# Costs                        0.000000   0.000000      0.000000  0.000000
# Automated trading systems    0.000000   0.000000      0.000000  0.000000
# Commerce                     0.000000   0.000000      0.000000  0.033260
# Finance                      0.000000   0.000000      0.000000  0.000000
# Algorithms                   0.000000   0.000000      0.000000  0.062500
#
#                            Vaitonis M.  Maringer D.  Zhang H.  Masteika S.  \
# Data mining                   0.000000     0.000000  0.000000     0.000000
# Automated trading             0.000000     0.114520  0.000000     0.000000
# Forecasting                   0.000000     0.000000  0.000000     0.000000
# Algorithmic trading           0.081923     0.036637  0.040962     0.073274
# Trading strategies            0.150756     0.067420  0.000000     0.134840
# Investments                   0.000000     0.124035  0.138675     0.000000
# Automation                    0.000000     0.081650  0.000000     0.000000
# High-frequency trading        0.153393     0.068599  0.076696     0.137199
# Electronic trading            0.128154     0.000000  0.042718     0.114624
# Financial data processing     0.000000     0.065938  0.000000     0.000000
# Financial markets             0.102062     0.000000  0.051031     0.091287
# trading                       0.000000     0.074536  0.000000     0.000000
# Artificial intelligence       0.000000     0.133333  0.074536     0.000000
# High frequency                0.000000     0.000000  0.000000     0.000000
# Profitability                 0.081111     0.072548  0.000000     0.072548
# Costs                         0.080064     0.143223  0.080064     0.071611
# Automated trading systems     0.000000     0.000000  0.000000     0.089443
# Commerce                      0.099779     0.089245  0.099779     0.089245
# Finance                       0.000000     0.057260  0.128037     0.000000
# Algorithms                    0.000000     0.055902  0.000000     0.000000
#
#                            Kompella R.R.  Hudson R.    Luk W.  Zhang G.
# Data mining                     0.000000   0.000000  0.000000  0.000000
# Automated trading               0.064018   0.000000  0.057260  0.000000
# Forecasting                     0.000000   0.000000  0.000000  0.083333
# Algorithmic trading             0.122885   0.000000  0.000000  0.000000
# Trading strategies              0.000000   0.000000  0.000000  0.075378
# Investments                     0.000000   0.000000  0.000000  0.000000
# Automation                      0.000000   0.000000  0.000000  0.000000
# High-frequency trading          0.000000   0.115045  0.102899  0.038348
# Electronic trading              0.000000   0.000000  0.000000  0.042718
# Financial data processing       0.000000   0.000000  0.065938  0.073721
# Financial markets               0.000000   0.051031  0.091287  0.000000
# trading                         0.000000   0.000000  0.074536  0.000000
# Artificial intelligence         0.000000   0.000000  0.066667  0.000000
# High frequency                  0.000000   0.000000  0.073521  0.000000
# Profitability                   0.000000   0.000000  0.000000  0.000000
# Costs                           0.000000   0.000000  0.000000  0.000000
# Automated trading systems       0.000000   0.000000  0.000000  0.000000
# Commerce                        0.000000   0.000000  0.089245  0.066519
# Finance                         0.000000   0.000000  0.057260  0.000000
# Algorithms                      0.000000   0.000000  0.055902  0.000000

# %%
rdf.crosscorrelation(
    termA='keywords (cleaned)',
    sepA=';',
    termB='Authors',
    sepB=','
).sankey_plot()

# %% [markdown]
# ## Factor analysis

# %%
rdf.factor_analysis(
    term='keywords (cleaned)', 
    sep=';', 
    n_components=5, 
    N=40).head(20)

# %%
rdf.factor_analysis(
    term='keywords (cleaned)', 
    sep=';', 
    n_components=5, 
    N=40).heatmap()
